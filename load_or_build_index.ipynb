# %%
import sys
from IPython.display import Markdown
from src_index.token_catcher import Usage
from src_index.ho3_sample_policy_index import build_ho3_sample_policy_index
from src_index.ho3_sub_query_engine import build_ho3_sub_query_engine

# %%
from llama_index import SimpleDirectoryReader

# %%
sample_ho3_policy_docs = SimpleDirectoryReader(input_files=['./data//HO3_sample.pdf']).load_data()
tx_doi_docs = SimpleDirectoryReader(input_files=['./data/tx_doi_code/TX_INSURANCE_CODE_All_3872.pdf']).load_data()
bldg_codes_docs = SimpleDirectoryReader(input_files=['./data/building_codes/building_codes.pdf']).load_data()

# %%
from llama_index import ServiceContext
from llama_index.llms import OpenAI

# add model specs to defaults
service_context = ServiceContext.from_defaults(llm=OpenAI(model="gpt-3.5-turbo", temperature=0))

# %%
usage = Usage()

# %%
from llama_index import StorageContext, VectorStoreIndex, load_index_from_storage

try:
    ho3_index = load_index_from_storage(StorageContext.from_defaults(persist_dir="./ho3_sample_policy_meta_index"))
    tx_doi_index = load_index_from_storage(StorageContext.from_defaults(persist_dir="./tx_doi_index"))
    bldg_codes_index = load_index_from_storage(StorageContext.from_defaults(persist_dir="./_property_index_storage"))
    
except:
    ho3_index = build_ho3_sample_policy_index(sample_ho3_policy_docs, llm_metadata=True)
    ho3_index.storage_context.persist(persist_dir="./ho3_sample_policy_meta_index")
    
    tx_doi_index = VectorStoreIndex.from_documents(tx_doi_docs)
    tx_doi_index.storage_context.persist(persist_dir="./tx_doi_index")
    
    bldg_codes_index = VectorStoreIndex.from_documents(bldg_codes_docs)
    bldg_codes_index.storage_context.persist(persist_dir="./_property_index_storage")

# %%
usage.total_tokens()
# Out:
# 2163272

# %%
from llama_index.tools import QueryEngineTool

# create a query engine tool for each folder
ho3_tool = QueryEngineTool.from_defaults(
    query_engine=ho3_index.as_query_engine(), 
    name="Insurance Policy", 
    description="Useful for answering questions about insurance coverage or general policy wording. "
)

doi_tool = QueryEngineTool.from_defaults(
    query_engine=tx_doi_index.as_query_engine(),
    name="TX DOI",
    description="Useful for answering questions about insurance related rules or regulations. "
)

bldg_tool = QueryEngineTool.from_defaults(
    query_engine=bldg_codes_index.as_query_engine(),
    name="Building Codes",
    description="Useful for answering questions about repairing buildings or other structures. "
)

# %%
# needed for notebooks
import nest_asyncio
nest_asyncio.apply()

from llama_index.query_engine import SubQuestionQueryEngine
from llama_index.response_synthesizers import get_response_synthesizer

query_engine = SubQuestionQueryEngine.from_defaults(
    query_engine_tools=[
        ho3_tool,
        doi_tool,
        bldg_tool,
    ],
    verbose=True
)

# %%
response = query_engine.query("Does the policy cover damage from a plumbing leak? If so are there any limitations?")
Markdown(f"{response}")
# Out:
# Generated 2 sub questions.
# [Insurance Policy] Q: Does the policy cover damage from a plumbing leak?
# [Insurance Policy] Q: Are there any limitations on coverage for damage from a plumbing leak?
# [Insurance Policy] A: Yes, the policy does cover damage from a plumbing leak.
# [Insurance Policy] A: Yes, there are limitations on coverage for damage from a plumbing leak. The policy does not cover loss to the system or appliance from which the water or steam escaped. Additionally, loss caused by mold, fungus, or wet rot is not covered unless it is hidden within the walls, ceilings, floors, or above the ceilings of a structure.
# Yes, the policy does cover damage from a plumbing leak, but there are limitations. The policy does not cover loss to the system or appliance from which the water or steam escaped, and loss caused by mold, fungus, or wet rot is not covered unless it is hidden within the walls, ceilings, floors, or above the ceilings of a structure.

# %%
Markdown(f"{response.source_nodes[1].node.text}")
# Out:
# Sub question: Are there any limitations on coverage for damage from a plumbing leak?
# Response: Yes, there are limitations on coverage for damage from a plumbing leak. The policy does not cover loss to the system or appliance from which the water or steam escaped. Additionally, loss caused by mold, fungus, or wet rot is not covered unless it is hidden within the walls, ceilings, floors, or above the ceilings of a structure.

# %% [markdown]
# ### Generate Evaluation Dataset

# %%
from llama_index import Document

all_text = ""

for doc in sample_ho3_policy_docs:
    all_text += doc.text

text_document = Document(text=all_text)

# %%
import os
import random
random.seed(42)

from llama_index import ServiceContext
from llama_index.prompts import Prompt
from llama_index.llms import OpenAI
from llama_index.evaluation import DatasetGenerator

gpt4_service_context = ServiceContext.from_defaults(llm=OpenAI(llm="gpt-4", temperature=0))

question_dataset = []
if os.path.exists("question_dataset.txt"):
    with open("question_dataset.txt", "r") as f:
        for line in f:
            question_dataset.append(line.strip())
else:
    # generate questions
    data_generator = DatasetGenerator.from_documents(
        [text_document],
        text_question_template=Prompt(
            "A sample from the Insurance Policy documentation is below.\n"
            "---------------------\n"
            "{context_str}\n"
            "---------------------\n"
            "Using the documentation sample, carefully follow the instructions below:\n"
            "{query_str}"
        ),
        question_gen_query=(
            "You are an evaluator for a search pipeline. Your task is to write a single question "
            "using the provided documentation sample above to test the search pipeline. The question should "
            "reference specific coverage terms or provisions. Restrict the question to the "
            "context information provided.\n"
            "Question: "
        ),
        # set this to be low, so we can generate more questions
        service_context=gpt4_service_context
    )
    generated_questions = data_generator.generate_questions_from_nodes()

    # randomly pick 10 questions from each dataset
    generated_questions = random.sample(generated_questions, 10)
    question_dataset.extend(generated_questions)

    print(f"Generated {len(question_dataset)} questions.")

    # save the questions!
    with open("question_dataset.txt", "w") as f:
        for question in question_dataset:
            f.write(f"{question.strip()}\n")
# Out:
# Generated 10 questions.

# %%
print(random.sample(question_dataset, 5))
# Out:
# ['Does the insurance policy cover damage caused by freezing to a plumbing system or household appliance?', 'What is the coverage limit for loss by theft of silverware, silver-plated ware, goldware, gold-plated ware, platinumware, platinum-plated ware and pewterware?', 'What is the limit of liability for debris removal under Coverage D?', 'What is the maximum amount of coverage for loss assessment under Coverage E?', 'What is the time frame for submitting a sworn statement of loss for C. Damage To Property Of Others under Section II – Additional Coverages?']

# %% [markdown]
# ### Evaluate Responses for Hallucination

# %%
import time
import asyncio
import nest_asyncio
nest_asyncio.apply()

from llama_index import Response

def evaluate_query_engine(evaluator, query_engine, questions):
    async def run_query(query_engine, q):
        try:
            return await query_engine.aquery(q)
        except:
            return Response(response="Error, query failed.")

    total_correct = 0
    all_results = []
    for batch_size in range(0, len(questions), 5):
        batch_qs = questions[batch_size:batch_size+5]

        tasks = [run_query(query_engine, q) for q in batch_qs]
        responses = asyncio.run(asyncio.gather(*tasks))
        print(f"finished batch {(batch_size // 5) + 1} out of {len(questions) // 5}")

        for response in responses:
            eval_result = 1 if "YES" in evaluator.evaluate(response) else 0
            total_correct += eval_result
            all_results.append(eval_result)
        
        # helps avoid rate limits
        time.sleep(1)

    return total_correct, all_results

# %%
from llama_index.evaluation import ResponseEvaluator

# gpt-4 evaluator!
evaluator = ResponseEvaluator(service_context=gpt4_service_context)

total_correct, all_results = evaluate_query_engine(evaluator, query_engine, question_dataset)

print(f"Hallucination? Scored {total_correct} out of {len(question_dataset)} questions correctly.")
# Out:
# Generated 1 sub questions.
# [Insurance Policy] Q: What is the definition of 'Motor Vehicle Liability' in the Insurance Policy?
# Generated 2 sub questions.
# [Insurance Policy] Q: What is the maximum amount of coverage for loss assessment under Coverage E according to the Insurance Policy tool?
# [TX DOI] Q: What is the maximum amount of coverage for loss assessment under Coverage E according to the TX DOI tool?
# [Insurance Policy] A:
# Motor Vehicle Liability is defined as any liability arising from the use of a motor vehicle that is registered for use on public roads or property, or is required to be registered for use on public roads or property, or is being operated in, or practicing for, any prearranged or organized race, speed contest or other competition; rented to others; used to carry persons or cargo for a charge; or used for any business purpose except for a motorized golf cart while on a golfing facility.
# [Insurance Policy] A:
# The maximum amount of coverage for loss assessment under Coverage E according to the Insurance Policy is $1,000.
# [TX DOI] A:
# There is no mention of Coverage E in the context information provided, so it is not possible to answer this question.
# Generated 5 sub questions.
# [Insurance Policy] Q: What is the limit of liability for grave markers on the residence premises?
# [Insurance Policy] Q: What is the limit of liability for grave markers away from the residence premises?
# [Insurance Policy] Q: What is the limit of liability for mausoleums on the residence premises?
# [Insurance Policy] Q: What is the limit of liability for mausoleums away from the residence premises?
# [Insurance Policy] Q: What is the limit of liability for loss caused by a Peril Insured Against under Coverage C?
# Generated 5 sub questions.
# [Insurance Policy] Q: Does the insurance policy cover loss caused by the discharge, leakage, or overflow from within a plumbing system?
# [Insurance Policy] Q: Does the insurance policy cover loss caused by the discharge, leakage, or overflow from within a heating system?
# [Insurance Policy] Q: Does the insurance policy cover loss caused by the discharge, leakage, or overflow from within an air conditioning system?
# [Insurance Policy] Q: Does the insurance policy cover loss caused by the discharge, leakage, or overflow from within an automatic fire protective sprinkler system?
# [Insurance Policy] Q: Does the insurance policy cover loss caused by the discharge, leakage, or overflow from a household appliance due to freezing?
# [Insurance Policy] A:
# The limit of liability for grave markers on the residence premises is $5,000.
# [Insurance Policy] A:
# The limit of liability for grave markers away from the residence premises is $5,000.
# [Insurance Policy] A:
# The limit of liability for mausoleums away from the residence premises is not specified in the context information.
# [Insurance Policy] A:
# The limit of liability for mausoleums on the residence premises is not specified in the context information provided.
# [Insurance Policy] A:
# The limit of liability for loss caused by a Peril Insured Against under Coverage C is the limit of liability for Coverage C shown in the Declarations.
# Generated 7 sub questions.
# [Insurance Policy] Q: What is the coverage limit for loss by theft of silverware?
# [Insurance Policy] Q: What is the coverage limit for loss by theft of silver-plated ware?
# [Insurance Policy] Q: What is the coverage limit for loss by theft of goldware?
# [Insurance Policy] Q: What is the coverage limit for loss by theft of gold-plated ware?
# [Insurance Policy] Q: What is the coverage limit for loss by theft of platinumware?
# [Insurance Policy] Q: What is the coverage limit for loss by theft of platinum-plated ware?
# [Insurance Policy] Q: What is the coverage limit for loss by theft of pewterware?
# [Insurance Policy] A:
# $2,500
# [Insurance Policy] A:
# $2,500
# [Insurance Policy] A:
# $2,500
# [Insurance Policy] A:
# $2,500
# [Insurance Policy] A:
# No, the insurance policy does not cover loss caused by the discharge, leakage, or overflow from a household appliance due to freezing. This is stated in Peril Insured Against 14. Freezing, which states that the policy does not cover loss caused by or resulting from freezing.
# [Insurance Policy] A:
# $2,500
# [Insurance Policy] A:
# $2,500
# [Insurance Policy] A:
# Yes, the insurance policy covers loss caused by the discharge, leakage, or overflow from within a heating system. This is covered under Peril 13. Sudden And Accidental Tearing Apart, Cracking, Burning Or Bulging and Peril 14. Freezing.
# [Insurance Policy] A:
# Yes, the insurance policy covers loss caused by the discharge, leakage, or overflow from within a plumbing system. This is stated in Section I – Exclusion A. 3. Water Damage, c. (5) and (6).
# [Insurance Policy] A:
# The coverage limit for loss by theft of silverware is $2,500.
# [Insurance Policy] A:
# Yes, the insurance policy covers loss caused by the discharge, leakage, or overflow from within an automatic fire protective sprinkler system. This is stated in Exception To c. (6) under Coverage A and B, which states that the policy covers loss to property covered under Coverage A or B resulting from an accidental discharge or overflow of water or steam from within an automatic fire protective sprinkler system.
# [Insurance Policy] A:
# Yes, the insurance policy covers loss caused by the discharge, leakage, or overflow from within an air conditioning system. This is covered under the Sudden and Accidental Tearing Apart, Cracking, Burning or Bulging peril (13) and the Sudden and Accidental Damage from Artificially Generated Electrical Current peril (15).
# finished batch 1 out of 2
# Generated 3 sub questions.
# [Insurance Policy] Q: What is the limit of liability for debris removal under Coverage D?
# [Insurance Policy] Q: What is the coverage for debris removal under Coverage D?
# [Insurance Policy] Q: What are the policy wording for debris removal under Coverage D?
# Generated 2 sub questions.
# [Insurance Policy] Q: What is the coverage provided for losses resulting from a nuclear hazard?
# [TX DOI] Q: Are there any specific rules or regulations regarding insurance coverage for losses resulting from a nuclear hazard?
# [Insurance Policy] A:
# The limit of liability for debris removal under Coverage D is up to 10% of the limit of liability that applies to Coverage A.
# [TX DOI] A:
# No, there are no specific rules or regulations regarding insurance coverage for losses resulting from a nuclear hazard mentioned in the context information provided.
# Generated 5 sub questions.
# [Insurance Policy] Q: What is the coverage for bodily injury caused by a nuclear weapon?
# [Insurance Policy] Q: What is the coverage for property damage caused by a nuclear weapon?
# [TX DOI] Q: What are the insurance related rules or regulations regarding bodily injury caused by a nuclear weapon?
# [TX DOI] Q: What are the insurance related rules or regulations regarding property damage caused by a nuclear weapon?
# [Building Codes] Q: What are the building codes for repairing buildings or other structures damaged by a nuclear weapon?
# [Insurance Policy] A:
# The coverage provided for losses resulting from a nuclear hazard is that direct loss by fire resulting from the nuclear hazard is covered, but any other loss caused directly or indirectly by nuclear hazard is not covered.
# Generated 7 sub questions.
# [Insurance Policy] Q: What is the coverage for damage caused by freezing to a plumbing system?
# [Insurance Policy] Q: What is the coverage for damage caused by freezing to a household appliance?
# [Insurance Policy] Q: Are there any specific exclusions or limitations for damage caused by freezing in the insurance policy?
# [TX DOI] Q: What are the rules and regulations regarding coverage for damage caused by freezing according to TX DOI?
# [TX DOI] Q: Are there any specific requirements or conditions for coverage of damage caused by freezing according to TX DOI?
# [Building Codes] Q: What are the building codes related to preventing damage caused by freezing?
# [Building Codes] Q: What are the building codes related to repairing damage caused by freezing?
# [TX DOI] A:
# There are no specific insurance related rules or regulations regarding bodily injury caused by a nuclear weapon in the Texas Insurance Code.
# [Insurance Policy] A:
# The coverage for property damage caused by a nuclear weapon is excluded under Exclusion A.7. of the Homeowner's Insurance Policy.
# [Insurance Policy] A:
# Under Coverage D, the policy wording for debris removal is:
#
# We will pay your reasonable expense for the removal of: (1) Debris of covered property if a Peril Insured Against that applies to the damaged property causes the loss; or (2) Ash, dust or particles from a volcanic eruption that has caused direct loss to a building or property contained in a building. This expense is included in the limit of liability that applies to the damaged property. If the amount to be paid for the actual damage to the property plus the debris removal expense is more than the limit of liability for the damaged property, an additional 5% of that limit is available for such expense.
#
# We will also pay your reasonable expense, up to $1,000, for the removal from the "residence premises" of: (1) Your tree (s) felled by the peril of Windstorm or Hail or Weight of Ice, Snow or Sleet; or (2) A neighbor's tree (s) felled by a Peril Insured Against under Coverage C; provided the tree (s) damage (s) a covered structure; or (3) Does not damage a covered structure, but blocks (s) a driveway on the "residence premises" which prevent (s) a "motor vehicle", that is registered for use on public roads or property, from entering or leaving the "residence premises".
# Generated 7 sub questions.
# [Insurance Policy] A:
# Under Coverage D, we will pay the reasonable expense for the removal of debris of covered property if a Peril Insured Against that applies to the damaged property causes the loss. This expense is included in the limit of liability that applies to the damaged property. If the amount to be paid for the actual damage to the property plus the debris removal expense is more than the limit of liability for the damaged property, an additional 5% of that limit is available for such expense. We will also pay the reasonable expense, up to $1,000, for the removal from the "residence premises" of your tree (s) felled by the peril of Windstorm or Hail or Weight of Ice, Snow or Sleet, or a neighbor's tree (s) felled by a Peril Insured Against under Coverage C, provided the tree (s) damage (s) a covered structure or does not damage a covered structure but blocks (s) a driveway on the "residence premises" which prevent (s) a "motor vehicle", that is registered for use on public roads or property, from entering or leaving the "residence premises".
# [TX DOI] A:
# There are no specific insurance related rules or regulations regarding property damage caused by a nuclear weapon in the Texas Insurance Code.
# [Insurance Policy] Q: What is the time frame for submitting a sworn statement of loss for C. Damage To Property Of Others under Section II – Additional Coverages?
# [Insurance Policy] Q: What are the specific requirements for submitting a sworn statement of loss for C. Damage To Property Of Others under Section II – Additional Coverages?
# [Insurance Policy] Q: Are there any exceptions or extensions to the time frame for submitting a sworn statement of loss for C. Damage To Property Of Others under Section II – Additional Coverages?
# [TX DOI] Q: What are the rules and regulations regarding the time frame for submitting a sworn statement of loss for C. Damage To Property Of Others under Section II – Additional Coverages?
# [TX DOI] Q: Are there any penalties for not submitting a sworn statement of loss within the specified time frame for C. Damage To Property Of Others under Section II – Additional Coverages?
# [Building Codes] Q: What are the building code requirements for repairing damage to property of others under Section II – Additional Coverages?
# [Building Codes] Q: Are there any specific building code provisions related to damage to property of others under Section II – Additional Coverages?
# [Building Codes] A:
# There are no specific building codes for repairing buildings or other structures damaged by a nuclear weapon. However, the Building Code does provide general requirements for development located in flood hazard areas, including the subdivision of land, site improvements and installation of utilities, placement and replacement of manufactured homes, placement of recreational vehicles, new construction and repair, reconstruction, rehabilitation, or additions to new construction, substantial improvement of existing buildings and structures, including restoration after damage, and the installation of tanks. Additionally, the Building Code requires that buildings and structures erected in areas prone to flooding be constructed by methods and practices that minimize flood damage.
# [TX DOI] A:
# There are no rules and regulations regarding coverage for damage caused by freezing according to TX DOI.
# [Insurance Policy] A:
# The coverage for damage caused by freezing to a household appliance is limited to losses covered under Peril Insured Against 14. Freezing, provided that the homeowner has used reasonable care to maintain heat in the building or shut off the water supply and drain all systems and appliances of water.
# [TX DOI] A:
# No, there are no specific requirements or conditions for coverage of damage caused by freezing according to TX DOI.
# [Insurance Policy] A:
# The coverage for bodily injury caused by a nuclear weapon is excluded from the Homeowner's Insurance Policy. This is stated in Section II – Additional Coverages, under the exclusion for War, which states that "Bodily injury" or "property damage" caused directly or indirectly by war, including the following and any consequence of any of the following: a. Undeclared war, civil war, insurrection, rebellion or revolution; b. Warlike act by a military force or military personnel; or c. Destruction, seizure or use for a military purpose. Discharge of a nuclear weapon will be deemed a warlike act even if accidental.
# [Building Codes] A:
# There are no building codes related to repairing damage caused by freezing in the provided context information.
# [Insurance Policy] A:
# The coverage for damage caused by freezing to a plumbing system is that the homeowner must have used reasonable care to maintain heat in the building or shut off the water supply and drain all systems and appliances of water. However, if the building is protected by an automatic fire protective sprinkler system, the homeowner must use reasonable care to continue the water supply and maintain heat in the building for coverage to apply.
# [Insurance Policy] A:
# Yes, there are specific exclusions or limitations for damage caused by freezing in the insurance policy. Peril 14. Freezing states that coverage does not apply if the building is not protected by an automatic fire protective sprinkler system and reasonable care has not been taken to maintain heat in the building or shut off the water supply and drain all systems and appliances of water. Additionally, this peril does not cover loss caused by or resulting from freezing.
# [Insurance Policy] A:
# The time frame for submitting a sworn statement of loss for C. Damage To Property Of Others under Section II – Additional Coverages is 60 days after receiving notice from the insurance company.
# [Building Codes] A:
# The building code requirements for repairing damage to property of others under Section II – Additional Coverages are not specified in the context information provided.
# [Insurance Policy] A:
# No, there are no exceptions or extensions to the time frame for submitting a sworn statement of loss for C. Damage To Property Of Others under Section II – Additional Coverages.
# [TX DOI] A:
# Under Section II – Additional Coverages, an insurer must provide the claimant with the forms usually provided by the insurer for filing proof of loss within 16 days of receiving notice of the claim. If the forms are not provided within 16 days, the claimant shall be considered to have complied with the requirements of the policy as to proof of loss on submitting, within the time fixed in the policy, a sworn statement of the loss. Additionally, an insurer must provide the policyholder with a list of claims charged against the policy and payments made on each claim within 30 days of receiving the request for the information.
# [Building Codes] A:
# No, there are no specific building code provisions related to damage to property of others under Section II – Additional Coverages.
# [TX DOI] A:
# Yes, there are penalties for not submitting a sworn statement of loss within the specified time frame for C. Damage To Property Of Others under Section II – Additional Coverages. According to Section 542.060 of the Texas Insurance Code, if an insurer that is liable for a claim under an insurance policy is not in compliance with this subchapter, the insurer is liable to pay the holder of the policy or the beneficiary making the claim under the policy, in addition to the claim, damages and other items as provided by Section 542.060.
# [Insurance Policy] A:
# The specific requirements for submitting a sworn statement of loss for C. Damage To Property Of Others under Section II – Additional Coverages are:
#
# 1. Provide records and documents requested and permit us to make copies;
# 2. Submit to examination under oath, while not in the presence of another "insured", and sign the same;
# 3. Send to us, within 60 days after our request, your signed, sworn proof of loss which sets forth, to the best of your knowledge and belief:
# a. The time and cause of loss;
# b. The interests of all "insureds" and all others in the property involved and all liens on the property;
# c. Other insurance which may cover the loss;
# d. Changes in title or occupancy of the property during the term of the policy;
# e. Evidence or affidavit that supports a claim under E. 6. Credit Card, Electronic Fund Transfer Card Or Access Device, Forgery And Counterfeit Money under Section I – Property Coverages, stating the amount and cause of loss.
# [Building Codes] A:
# The building codes related to preventing damage caused by freezing are:
# a. Disable mechanical heating or reset the heating setpoint to 55°F or lower within five minutes of the door opening; and
# b. Disable mechanical cooling or reset the cooling setpoint to 90°F or greater within five minutes of the door opening. Mechanical cooling may remain enabled if outdoor air temperature is below space temperature.
# Exceptions:
# 1. Building entries with automatic closing devices.
# 2. Any space without a thermostat.
# 3. Alterations to existing buildings.
# 4. Loading docks.
# 5. Radiant heating systems.
# 6. Where HVAC equipment must remain on for safety, sanitation, or other health related reasons.
# 7.4.4.5 Electric water heater timers. For Group R buildings electric resistance water heaters must be installed in conjunction with a preprogrammed water heater timer. The timer shall be preprogrammed to turn the water heater off between the hours of 3:00 p.m. and 7:00 p.m. from June 1 to September 30 and from 12:00 a.m. to 4:00 a.m. throughout the year. The timer shall have a readily accessible override, as defined by the building official administrative rule, capable of restoring power to the water heater for one hour when activated.
# Exception: Where approved water heater demand response capability has been installed.
# finished batch 2 out of 2
# Hallucination? Scored 4 out of 10 questions correctly.

# %%
import numpy as np

hallucinated_questions = np.array(question_dataset)[np.array(all_results) == 0]
print(hallucinated_questions)
# Out:
# ['What is the maximum amount of coverage for loss assessment under Coverage E?'
#  'Does the insurance policy cover loss caused by the discharge, leakage, or overflow from within a plumbing, heating, air conditioning, or automatic fire protective sprinkler system or of a household appliance due to freezing?'
#  'What is the coverage for "bodily injury" or "property damage" caused by a nuclear weapon?'
#  'What is the limit of liability for debris removal under Coverage D?'
#  'What is the time frame for submitting a sworn statement of loss for C. Damage To Property Of Others under Section II – Additional Coverages?'
#  'Does the insurance policy cover damage caused by freezing to a plumbing system or household appliance?']

# %%
response = query_engine.query('Does the insurance policy cover damage caused by freezing to a plumbing system or household appliance?')
print(str(response))
print("-----------------")
print(response.get_formatted_sources(length=1000))
# Out:
# Generated 7 sub questions.
# [Insurance Policy] Q: What is the coverage for damage caused by freezing to a plumbing system?
# [Insurance Policy] Q: What is the coverage for damage caused by freezing to a household appliance?
# [Insurance Policy] Q: Are there any specific exclusions or limitations for damage caused by freezing in the insurance policy?
# [TX DOI] Q: What are the rules and regulations regarding coverage for damage caused by freezing according to TX DOI?
# [TX DOI] Q: Are there any specific requirements or conditions for coverage of damage caused by freezing according to TX DOI?
# [Building Codes] Q: What are the building codes related to preventing damage caused by freezing?
# [Building Codes] Q: What are the building codes related to repairing damage caused by freezing?
# [TX DOI] A:
# There are no rules and regulations regarding coverage for damage caused by freezing according to TX DOI.
# [TX DOI] A:
# No, there are no specific requirements or conditions for coverage of damage caused by freezing according to TX DOI.
# [Building Codes] A:
# There are no building codes related to repairing damage caused by freezing in the provided context information.
# [Insurance Policy] A:
# The coverage for damage caused by freezing to a household appliance is limited to losses covered under Peril Insured Against 14. Freezing, provided that the homeowner has used reasonable care to maintain heat in the building or shut off the water supply and drain all systems and appliances of water.
# [Insurance Policy] A:
# Yes, there are specific exclusions or limitations for damage caused by freezing in the insurance policy. Peril 14. Freezing states that coverage does not apply if the building is not protected by an automatic fire protective sprinkler system and reasonable care has not been taken to maintain heat in the building or shut off the water supply and drain all systems and appliances of water. Additionally, this peril does not cover loss caused by or resulting from freezing.
# [Insurance Policy] A:
# The coverage for damage caused by freezing to a plumbing system is that the homeowner must have used reasonable care to maintain heat in the building or shut off the water supply and drain all systems and appliances of water. However, if the building is protected by an automatic fire protective sprinkler system, the homeowner must use reasonable care to continue the water supply and maintain heat in the building for coverage to apply.
# [Building Codes] A:
# The building codes related to preventing damage caused by freezing are:
# a. Disable mechanical heating or reset the heating setpoint to 55°F or lower within five minutes of the door opening; and
# b. Disable mechanical cooling or reset the cooling setpoint to 90°F or greater within five minutes of the door opening. Mechanical cooling may remain enabled if outdoor air temperature is below space temperature.
# Exceptions:
# 1. Building entries with automatic closing devices.
# 2. Any space without a thermostat.
# 3. Alterations to existing buildings.
# 4. Loading docks.
# 5. Radiant heating systems.
# 6. Where HVAC equipment must remain on for safety, sanitation, or other health related reasons.
# 7.4.4.5 Electric water heater timers. For Group R buildings electric resistance water heaters must be installed in conjunction with a preprogrammed water heater timer. The timer shall be preprogrammed to turn the water heater off between the hours of 3:00 p.m. and 7:00 p.m. from June 1 to September 30 and from 12:00 a.m. to 4:00 a.m. throughout the year. The timer shall have a readily accessible override, as defined by the building official administrative rule, capable of restoring power to the water heater for one hour when activated.
# Exception: Where approved water heater demand response capability has been installed.
#
# Yes, the insurance policy covers damage caused by freezing to a plumbing system or household appliance, provided that the homeowner has used reasonable care to maintain heat in the building or shut off the water supply and drain all systems and appliances of water. However, if the building is protected by an automatic fire protective sprinkler system, the homeowner must use reasonable care to continue the water supply and maintain heat in the building for coverage to apply.
# -----------------
# > Source (Doc id: 0368e45f-c439-4c4f-a7b8-71a57fe432c7): Sub question: What is the coverage for damage caused by freezing to a plumbing system?
# Response:
# The coverage for damage caused by freezing to a plumbing system is that the homeowner must have used reasonable care to maintain heat in the building or shut off the water supply and drain all systems and appliances of water. However, if the building is protected by an automatic fire protective sprinkler system, the homeowner must use reasonable care to continue the water supply and maintain heat in the building for coverage to apply....
#
# > Source (Doc id: 4f2dc9c1-11d1-4642-ad4d-0d66e53b8851): Sub question: What is the coverage for damage caused by freezing to a household appliance?
# Response:
# The coverage for damage caused by freezing to a household appliance is limited to losses covered under Peril Insured Against 14. Freezing, provided that the homeowner has used reasonable care to maintain heat in the building or shut off the water supply and drain all systems and appliances of water....
#
# > Source (Doc id: a5a8bd0e-4558-487e-84d9-4df275493efa): Sub question: Are there any specific exclusions or limitations for damage caused by freezing in the insurance policy?
# Response:
# Yes, there are specific exclusions or limitations for damage caused by freezing in the insurance policy. Peril 14. Freezing states that coverage does not apply if the building is not protected by an automatic fire protective sprinkler system and reasonable care has not been taken to maintain heat in the building or shut off the water supply and drain all systems and appliances of water. Additionally, this peril does not cover loss caused by or resulting from freezing....
#
# > Source (Doc id: 63f422c2-748d-4db0-9ea8-82d0784ef73e): Sub question: What are the rules and regulations regarding coverage for damage caused by freezing according to TX DOI?
# Response:
# There are no rules and regulations regarding coverage for damage caused by freezing according to TX DOI....
#
# > Source (Doc id: dc0e5abe-c189-4400-96a5-94735143b1aa): Sub question: Are there any specific requirements or conditions for coverage of damage caused by freezing according to TX DOI?
# Response:
# No, there are no specific requirements or conditions for coverage of damage caused by freezing according to TX DOI....
#
# > Source (Doc id: 6a8be0b8-82e4-4621-a80c-c722cac3f874): Sub question: What are the building codes related to preventing damage caused by freezing?
# Response:
# The building codes related to preventing damage caused by freezing are:
# a. Disable mechanical heating or reset the heating setpoint to 55°F or lower within five minutes of the door opening; and
# b. Disable mechanical cooling or reset the cooling setpoint to 90°F or greater within five minutes of the door opening. Mechanical cooling may remain enabled if outdoor air temperature is below space temperature.
# Exceptions:
# 1. Building entries with automatic closing devices.
# 2. Any space without a thermostat.
# 3. Alterations to existing buildings.
# 4. Loading docks.
# 5. Radiant heating systems.
# 6. Where HVAC equipment must remain on for safety, sanitation, or other health related reasons.
# 7.4.4.5 Electric water heater timers. For Group R buildings electric resistance water heaters must be installed in conjunction with a preprogrammed water heater timer. The timer shall be preprogrammed...
#
# > Source (Doc id: 921bfa77-f421-4654-8bc6-4a34aad23a0e): Sub question: What are the building codes related to repairing damage caused by freezing?
# Response:
# There are no building codes related to repairing damage caused by freezing in the provided context information....

# %%
response = query_engine.query('Does the insurance policy cover loss caused by the discharge, leakage, or overflow from within a plumbing, heating, or air conditioning system?')
print(str(response))
print("-----------------")
print(response.get_formatted_sources(length=1000))
# Out:
# Generated 3 sub questions.
# [Insurance Policy] Q: Does the insurance policy cover loss caused by the discharge, leakage, or overflow from within a plumbing system?
# [Insurance Policy] Q: Does the insurance policy cover loss caused by the discharge, leakage, or overflow from within a heating system?
# [Insurance Policy] Q: Does the insurance policy cover loss caused by the discharge, leakage, or overflow from within an air conditioning system?
# [Insurance Policy] A:
# Yes, the insurance policy covers loss caused by the discharge, leakage, or overflow from within a plumbing system. This is stated in Section I – Exclusion A. 3. Water Damage, c. (5) and (6).
# [Insurance Policy] A:
# Yes, the insurance policy covers loss caused by the discharge, leakage, or overflow from within a heating system. This is covered under Peril 13. Sudden And Accidental Tearing Apart, Cracking, Burning Or Bulging and Peril 14. Freezing.
# [Insurance Policy] A:
# Yes, the insurance policy covers loss caused by the discharge, leakage, or overflow from within an air conditioning system. This is covered under the Sudden and Accidental Tearing Apart, Cracking, Burning or Bulging peril (13) and the Sudden and Accidental Damage from Artificially Generated Electrical Current peril (15).
#
# Yes, the insurance policy covers loss caused by the discharge, leakage, or overflow from within a plumbing, heating, or air conditioning system. This is covered under Section I – Exclusion A. 3. Water Damage, c. (5) and (6), Peril 13. Sudden And Accidental Tearing Apart, Cracking, Burning Or Bulging, Peril 14. Freezing, and the Sudden and Accidental Damage from Artificially Generated Electrical Current peril (15).
# -----------------
# > Source (Doc id: 0738de0c-7ed1-47c8-9aa4-73d62df60a24): Sub question: Does the insurance policy cover loss caused by the discharge, leakage, or overflow from within a plumbing system?
# Response:
# Yes, the insurance policy covers loss caused by the discharge, leakage, or overflow from within a plumbing system. This is stated in Section I – Exclusion A. 3. Water Damage, c. (5) and (6)....
#
# > Source (Doc id: 3b2d438d-2390-4324-9bea-cd8d1ed62337): Sub question: Does the insurance policy cover loss caused by the discharge, leakage, or overflow from within a heating system?
# Response:
# Yes, the insurance policy covers loss caused by the discharge, leakage, or overflow from within a heating system. This is covered under Peril 13. Sudden And Accidental Tearing Apart, Cracking, Burning Or Bulging and Peril 14. Freezing....
#
# > Source (Doc id: 9c7e4acd-8a2c-4fc7-8b41-a5a4c4873c9e): Sub question: Does the insurance policy cover loss caused by the discharge, leakage, or overflow from within an air conditioning system?
# Response:
# Yes, the insurance policy covers loss caused by the discharge, leakage, or overflow from within an air conditioning system. This is covered under the Sudden and Accidental Tearing Apart, Cracking, Burning or Bulging peril (13) and the Sudden and Accidental Damage from Artificially Generated Electrical Current peril (15)....

# %% [markdown]
# ### Answer Quality

# %%
import time
import asyncio
import nest_asyncio
nest_asyncio.apply()
from llama_index import Response

def evaluate_query_engine(evaluator, query_engine, questions):
    async def run_query(query_engine, q):
        try:
            return await query_engine.aquery(q)
        except:
            return Response(response="Error, query failed.")

    total_correct = 0
    all_results = []
    for batch_size in range(0, len(questions), 5):
        batch_qs = questions[batch_size:batch_size+5]

        tasks = [run_query(query_engine, q) for q in batch_qs]
        responses = asyncio.run(asyncio.gather(*tasks))
        print(f"finished batch {(batch_size // 5) + 1} out of {len(questions) // 5}")

        for question, response in zip(batch_qs, responses):
            eval_result = 1 if "YES" in evaluator.evaluate(question, response) else 0
            total_correct += eval_result
            all_results.append(eval_result)
        
        # helps avoid rate limits
        time.sleep(1)

    return total_correct, all_results

# %%
from llama_index.evaluation import QueryResponseEvaluator

evaluator = QueryResponseEvaluator(service_context=gpt4_service_context)

total_correct, all_results = evaluate_query_engine(evaluator, query_engine, question_dataset)

print(f"Response satisfies the query? Scored {total_correct} out of {len(question_dataset)} questions correctly.")
# Out:
# Generated 1 sub questions.
# [Insurance Policy] Q: What is the definition of 'Motor Vehicle Liability' in the Insurance Policy?
# Generated 2 sub questions.
# [Insurance Policy] Q: What is the maximum amount of coverage for loss assessment under Coverage E according to the Insurance Policy tool?
# [TX DOI] Q: What is the maximum amount of coverage for loss assessment under Coverage E according to the TX DOI tool?
# [Insurance Policy] A:
# Motor Vehicle Liability is defined as any liability arising from the use of a motor vehicle that is registered for use on public roads or property, or is required to be registered for use on public roads or property, or is being operated in, or practicing for, any prearranged or organized race, speed contest or other competition; rented to others; used to carry persons or cargo for a charge; or used for any business purpose except for a motorized golf cart while on a golfing facility.
# [Insurance Policy] A:
# The maximum amount of coverage for loss assessment under Coverage E according to the Insurance Policy is $1,000.
# [TX DOI] A:
# There is no mention of Coverage E in the context information provided, so it is not possible to answer this question.
# Generated 5 sub questions.
# [Insurance Policy] Q: What is the limit of liability for grave markers on the residence premises?
# [Insurance Policy] Q: What is the limit of liability for grave markers away from the residence premises?
# [Insurance Policy] Q: What is the limit of liability for mausoleums on the residence premises?
# [Insurance Policy] Q: What is the limit of liability for mausoleums away from the residence premises?
# [Insurance Policy] Q: What is the limit of liability for loss caused by a Peril Insured Against under Coverage C?
# Generated 5 sub questions.
# [Insurance Policy] Q: Does the insurance policy cover loss caused by the discharge, leakage, or overflow from within a plumbing system?
# [Insurance Policy] Q: Does the insurance policy cover loss caused by the discharge, leakage, or overflow from within a heating system?
# [Insurance Policy] Q: Does the insurance policy cover loss caused by the discharge, leakage, or overflow from within an air conditioning system?
# [Insurance Policy] Q: Does the insurance policy cover loss caused by the discharge, leakage, or overflow from within an automatic fire protective sprinkler system?
# [Insurance Policy] Q: Does the insurance policy cover loss caused by the discharge, leakage, or overflow from a household appliance due to freezing?
# Generated 7 sub questions.
# [Insurance Policy] Q: What is the coverage limit for loss by theft of silverware?
# [Insurance Policy] Q: What is the coverage limit for loss by theft of silver-plated ware?
# [Insurance Policy] Q: What is the coverage limit for loss by theft of goldware?
# [Insurance Policy] Q: What is the coverage limit for loss by theft of gold-plated ware?
# [Insurance Policy] Q: What is the coverage limit for loss by theft of platinumware?
# [Insurance Policy] Q: What is the coverage limit for loss by theft of platinum-plated ware?
# [Insurance Policy] Q: What is the coverage limit for loss by theft of pewterware?
# [Insurance Policy] A:
# $2,500
# [Insurance Policy] A:
# $2,500
# [Insurance Policy] A:
# $2,500
# [Insurance Policy] A:
# $2,500
# [Insurance Policy] A:
# $2,500
# [Insurance Policy] A:
# $2,500
# [Insurance Policy] A:
# The limit of liability for grave markers on the residence premises is $5,000.
# [Insurance Policy] A:
# The coverage limit for loss by theft of silverware is $2,500.
# [Insurance Policy] A:
# The limit of liability for grave markers away from the residence premises is $5,000.
# [Insurance Policy] A:
# The limit of liability for mausoleums away from the residence premises is not specified in the context information.
# [Insurance Policy] A:
# Yes, the insurance policy covers loss caused by the discharge, leakage, or overflow from within a heating system. This is covered under Peril 13. Sudden And Accidental Tearing Apart, Cracking, Burning Or Bulging and Peril 14. Freezing.
# [Insurance Policy] A:
# The limit of liability for loss caused by a Peril Insured Against under Coverage C is the limit of liability for Coverage C shown in the Declarations.
# [Insurance Policy] A:
# The limit of liability for mausoleums on the residence premises is not specified in the context information provided.
# [Insurance Policy] A:
# Yes, the insurance policy covers loss caused by the discharge, leakage, or overflow from within an air conditioning system. This is covered under the Sudden and Accidental Tearing Apart, Cracking, Burning or Bulging peril (13) and the Sudden and Accidental Damage from Artificially Generated Electrical Current peril (15).
# [Insurance Policy] A:
# No, the insurance policy does not cover loss caused by the discharge, leakage, or overflow from a household appliance due to freezing. Peril Insured Against 14. Freezing states that loss caused by or resulting from freezing is not covered.
# [Insurance Policy] A:
# Yes, the insurance policy covers loss caused by the discharge, leakage, or overflow from within a plumbing system. This is stated in Section I – Exclusion A. 3. Water Damage, c. (5) and (6).
# [Insurance Policy] A:
# Yes, the insurance policy covers loss caused by the discharge, leakage, or overflow from within an automatic fire protective sprinkler system. This is stated in Section I – Exclusion A. 3. Water Damage, Paragraphs c. (6) which states that coverage applies to loss to property covered under Coverage A or B resulting from an accidental discharge or overflow of water or steam from within a storm drain, or water, steam or sewer pipe, off the "residence premises" or a plumbing, heating, air conditioning or automatic fire protective sprinkler system or household appliance on the "residence premises".
# finished batch 1 out of 2
# Generated 2 sub questions.
# [Insurance Policy] Q: What is the coverage provided for losses resulting from a nuclear hazard?
# [TX DOI] Q: Are there any specific rules or regulations regarding insurance coverage for losses resulting from a nuclear hazard?
# [Insurance Policy] A:
# The coverage provided for losses resulting from a nuclear hazard is that direct loss by fire resulting from the nuclear hazard is covered, but any other loss caused directly or indirectly by nuclear hazard is not covered.
# [TX DOI] A:
# No, there are no specific rules or regulations regarding insurance coverage for losses resulting from a nuclear hazard mentioned in the context information provided.
# Generated 5 sub questions.
# [Insurance Policy] Q: What is the coverage for bodily injury caused by a nuclear weapon?
# [Insurance Policy] Q: What is the coverage for property damage caused by a nuclear weapon?
# [TX DOI] Q: What are the insurance related rules or regulations regarding bodily injury caused by a nuclear weapon?
# [TX DOI] Q: What are the insurance related rules or regulations regarding property damage caused by a nuclear weapon?
# [Building Codes] Q: What are the building codes for repairing buildings or other structures damaged by a nuclear weapon?
# Generated 7 sub questions.
# [Insurance Policy] Q: What is the coverage for damage caused by freezing to a plumbing system?
# [Insurance Policy] Q: What is the coverage for damage caused by freezing to a household appliance?
# [Insurance Policy] Q: Are there any specific exclusions or limitations for damage caused by freezing in the insurance policy?
# [TX DOI] Q: What are the rules and regulations regarding coverage for damage caused by freezing according to TX DOI?
# [TX DOI] Q: Are there any specific requirements or conditions for coverage of damage caused by freezing according to TX DOI?
# [Building Codes] Q: What are the building codes related to preventing damage caused by freezing?
# [Building Codes] Q: What are the building codes related to repairing damage caused by freezing?
# Generated 7 sub questions.
# [Insurance Policy] Q: What is the limit of liability for debris removal under Coverage D?
# [Insurance Policy] Q: What is the coverage for debris removal under Coverage D?
# [Insurance Policy] Q: What are the policy wording for debris removal under Coverage D?
# [TX DOI] Q: What are the rules and regulations for debris removal under Coverage D?
# [TX DOI] Q: What are the insurance related rules and regulations for debris removal under Coverage D?
# [Building Codes] Q: What are the building codes for debris removal under Coverage D?
# [Building Codes] Q: What are the regulations for repairing buildings or other structures under Coverage D?
# [Insurance Policy] A:
# The coverage for property damage caused by a nuclear weapon is excluded under Exclusion A.7. of the Homeowner's Insurance Policy.
# [TX DOI] A:
# There are no specific insurance related rules or regulations regarding bodily injury caused by a nuclear weapon in the Texas Insurance Code.
# Generated 7 sub questions.
# [Building Codes] A:
# There are no specific building codes for repairing buildings or other structures damaged by a nuclear weapon. However, the Building Code does provide general requirements for development located in flood hazard areas, including the subdivision of land, site improvements and installation of utilities, placement and replacement of manufactured homes, placement of recreational vehicles, new construction and repair, reconstruction, rehabilitation, or additions to new construction, substantial improvement of existing buildings and structures, including restoration after damage, and the installation of tanks. Additionally, the Building Code requires that buildings and structures erected in areas prone to flooding be constructed by methods and practices that minimize flood damage.
# [Insurance Policy] A:
# The coverage for bodily injury caused by a nuclear weapon is excluded from the Homeowner's Insurance Policy.
# [TX DOI] A:
# There are no specific insurance related rules or regulations regarding property damage caused by a nuclear weapon in the Texas Insurance Code.
# [Insurance Policy] Q: What is the time frame for submitting a sworn statement of loss for C. Damage To Property Of Others under Section II – Additional Coverages?
# [Insurance Policy] Q: What are the specific requirements for submitting a sworn statement of loss for C. Damage To Property Of Others under Section II – Additional Coverages?
# [Insurance Policy] Q: Are there any exceptions or extensions to the time frame for submitting a sworn statement of loss for C. Damage To Property Of Others under Section II – Additional Coverages?
# [TX DOI] Q: What are the rules and regulations regarding the time frame for submitting a sworn statement of loss for C. Damage To Property Of Others under Section II – Additional Coverages?
# [TX DOI] Q: Are there any penalties for not submitting a sworn statement of loss within the specified time frame for C. Damage To Property Of Others under Section II – Additional Coverages?
# [Building Codes] Q: What are the building code requirements for repairing damage to property of others under Section II – Additional Coverages?
# [Building Codes] Q: Are there any specific building code provisions related to damage to property of others under Section II – Additional Coverages?
# [Building Codes] A:
# There are no building codes related to repairing damage caused by freezing in the provided context information.
# [Insurance Policy] A:
# The limit of liability for debris removal under Coverage D is up to 10% of the limit of liability that applies to Coverage A.
# [TX DOI] A:
# There are no rules and regulations for debris removal under Coverage D of the Texas Insurance Code.
# [TX DOI] A:
# There are no rules and regulations regarding coverage for damage caused by freezing according to TX DOI.
# [TX DOI] A:
# No, there are no specific requirements or conditions for coverage of damage caused by freezing according to TX DOI.
# [TX DOI] A:
# There are no specific insurance related rules and regulations for debris removal under Coverage D. However, Section 2210.208 of the Texas Insurance Code states that a windstorm and hail insurance policy issued by the association for a dwelling must include coverage for wind-driven rain damage, regardless of whether an opening is made by the wind. Additionally, Section 707.002 of the Texas Insurance Code states that a person insured under a property insurance policy must pay any deductible applicable to a first-party claim made under the policy.
# [Insurance Policy] A:
# Yes, there are specific exclusions or limitations for damage caused by freezing in the insurance policy. Peril 14. Freezing states that coverage does not apply if the building is not protected by an automatic fire protective sprinkler system and reasonable care has not been taken to maintain heat in the building or shut off the water supply and drain all systems and appliances of water. Additionally, this peril does not cover loss caused by or resulting from freezing.
# [Insurance Policy] A:
# The coverage for damage caused by freezing to a household appliance is limited to losses covered under Peril Insured Against 14. Freezing, provided that the homeowner has used reasonable care to maintain heat in the building or shut off the water supply and drain all systems and appliances of water.
# [Insurance Policy] A:
# The coverage for damage caused by freezing to a plumbing system is that the homeowner must have used reasonable care to maintain heat in the building or shut off the water supply and drain all systems and appliances of water. However, if the building is protected by an automatic fire protective sprinkler system, the homeowner must use reasonable care to continue the water supply and maintain heat in the building for coverage to apply.
# [Building Codes] A:
# Under Coverage D, debris removal is not specifically addressed in the building codes. However, Section 304.3.3 states that dumpsters and containers with an individual capacity of 1.5 cubic yards or more shall not be stored in buildings or placed within 10 feet of combustible walls, openings or combustible roof eave lines. Exceptions to this rule include dumpsters or containers in areas protected by an approved automatic sprinkler system installed throughout in accordance with Section 903.3.1.1 or 903.3.1.2, and storage in a structure of Type I or Type IIA construction located not less than 10 feet from other buildings and used exclusively for dumpster or container storage.
# [Insurance Policy] A:
# The time frame for submitting a sworn statement of loss for C. Damage To Property Of Others under Section II – Additional Coverages is 60 days after receiving notice from the insurance company.
# [Building Codes] A:
# No, there are no specific building code provisions related to damage to property of others under Section II – Additional Coverages.
# [Building Codes] A:
# The building code requirements for repairing damage to property of others under Section II – Additional Coverages are not specified in the context information provided.
# [Insurance Policy] A:
# No, there are no exceptions or extensions to the time frame for submitting a sworn statement of loss for C. Damage To Property Of Others under Section II – Additional Coverages.
# [Building Codes] A:
# Under Coverage D, the regulations for repairing buildings or other structures include examining the construction documents and preparing a finding with regard to the value of the proposed work (R105.3.1.1); establishing permit application time limits and requirements applicable to permit expiration and reactivation, including a review fee for expired permits (R105.5); registering an air conditioning and refrigeration contractor before performing any work regulated by this code (R105.10); providing information for construction in flood hazard areas (R106.1.4); establishing an inspection program for repair or replacement of certain components in individual owned and occupied dwellings (R109.5); allowing for modifications from flood plain management regulations (R112.5); and designing and constructing according to Article 3 (Flood Loads and Hazard Areas) if the work is a substantial improvement as defined in Section R202 (Definitions) (R301.2.4).
# [Insurance Policy] A:
# Under Coverage D, we will pay the reasonable expense for the removal of debris of covered property if a Peril Insured Against that applies to the damaged property causes the loss. This expense is included in the limit of liability that applies to the damaged property. If the amount to be paid for the actual damage to the property plus the debris removal expense is more than the limit of liability for the damaged property, an additional 5% of that limit is available for such expense. We will also pay the reasonable expense, up to $1,000, for the removal from the "residence premises" of your tree (s) felled by the peril of Windstorm or Hail or Weight of Ice, Snow or Sleet, or a neighbor's tree (s) felled by a Peril Insured Against under Coverage C, provided the tree (s) damage (s) a covered structure or does not damage a covered structure but blocks (s) a driveway on the "residence premises" which prevent (s) a "motor vehicle", that is registered for use on public roads or property, from entering or leaving the "residence premises".
# [TX DOI] A:
# Yes, there are penalties for not submitting a sworn statement of loss within the specified time frame for C. Damage To Property Of Others under Section II – Additional Coverages. According to Section 542.060 of the Texas Insurance Code, if an insurer that is liable for a claim under an insurance policy is not in compliance with this subchapter, the insurer is liable to pay the holder of the policy or the beneficiary making the claim under the policy, in addition to the claim, damages and other items as provided by Section 542.060.
# [Insurance Policy] A:
# Under Coverage D, the policy wording for debris removal is:
#
# We will pay your reasonable expense for the removal of: (1) Debris of covered property if a Peril Insured Against that applies to the damaged property causes the loss; or (2) Ash, dust or particles from a volcanic eruption that has caused direct loss to a building or property contained in a building. This expense is included in the limit of liability that applies to the damaged property. If the amount to be paid for the actual damage to the property plus the debris removal expense is more than the limit of liability for the damaged property, an additional 5% of that limit is available for such expense.
#
# We will also pay your reasonable expense, up to $1,000, for the removal from the "residence premises" of: (1) Your tree (s) felled by the peril of Windstorm or Hail or Weight of Ice, Snow or Sleet; or (2) A neighbor's tree (s) felled by a Peril Insured Against under Coverage C; provided the tree (s) damage (s) a covered structure; or (3) Does not damage a covered structure, but blocks (s) a driveway on the "residence premises" which prevent (s) a "motor vehicle", that is registered for use on public roads or property, from entering or leaving the "residence premises".
# [TX DOI] A:
# Under Section II – Additional Coverages, an insurer must provide the claimant with the forms usually provided by the insurer for filing proof of loss within 16 days of receiving notice of the claim. If the forms are not provided within 16 days, the claimant shall be considered to have complied with the requirements of the policy as to proof of loss on submitting, within the time fixed in the policy, a sworn statement of the loss. Additionally, an insurer must provide the policyholder with a list of claims charged against the policy and payments made on each claim within 30 days of receiving the request for the information.
# [Building Codes] A:
# The building codes related to preventing damage caused by freezing are:
# a. Disable mechanical heating or reset the heating setpoint to 55°F or lower within five minutes of the door opening; and
# b. Disable mechanical cooling or reset the cooling setpoint to 90°F or greater within five minutes of the door opening. Mechanical cooling may remain enabled if outdoor air temperature is below space temperature.
# Exceptions:
# 1. Building entries with automatic closing devices.
# 2. Any space without a thermostat.
# 3. Alterations to existing buildings.
# 4. Loading docks.
# 5. Radiant heating systems.
# 6. Where HVAC equipment must remain on for safety, sanitation, or other health related reasons.
# 7.4.4.5 Electric water heater timers. For Group R buildings electric resistance water heaters must be installed in conjunction with a preprogrammed water heater timer. The timer shall be preprogrammed to turn the water heater off between the hours of 3:00 p.m. and 7:00 p.m. from June 1 to September 30 and from 12:00 a.m. to 4:00 a.m. throughout the year. The timer shall have a readily accessible override, as defined by the building official administrative rule, capable of restoring power to the water heater for one hour when activated.
# Exception: Where approved water heater demand response capability has been installed.
# [Insurance Policy] A:
# The specific requirements for submitting a sworn statement of loss for C. Damage To Property Of Others under Section II – Additional Coverages are:
#
# 1. Provide records and documents requested and permit us to make copies;
# 2. Submit to examination under oath, while not in the presence of another "insured", and sign the same;
# 3. Send to us, within 60 days after our request, your signed, sworn proof of loss which sets forth, to the best of your knowledge and belief:
# a. The time and cause of loss;
# b. The interests of all "insureds" and all others in the property involved and all liens on the property;
# c. Other insurance which may cover the loss;
# d. Changes in title or occupancy of the property during the term of the policy;
# e. Evidence or affidavit that supports a claim under E. 6. Credit Card, Electronic Fund Transfer Card Or Access Device, Forgery And Counterfeit Money under Section I – Property Coverages, stating the amount and cause of loss.
# finished batch 2 out of 2
# Response satisfies the query? Scored 4 out of 10 questions correctly.

# %%
import numpy as np

unanswered_queries = np.array(question_dataset)[np.array(all_results) == 0]
print(unanswered_queries)
# Out:
# ['What is the maximum amount of coverage for loss assessment under Coverage E?'
#  'What is the coverage for "bodily injury" or "property damage" caused by a nuclear weapon?'
#  'What is the limit of liability for debris removal under Coverage D?'
#  'What is the time frame for submitting a sworn statement of loss for C. Damage To Property Of Others under Section II – Additional Coverages?'
#  'Does the insurance policy cover damage caused by freezing to a plumbing system or household appliance?'
#  'What is the coverage provided for losses resulting from a nuclear hazard?']

# %%
response = query_engine.query('What is the limit of liability for debris removal under Coverage D?')
print(str(response))
print("-----------------")
print(response.get_formatted_sources(length=256))
# Out:
# Generated 7 sub questions.
# [Insurance Policy] Q: What is the limit of liability for debris removal under Coverage D?
# [Insurance Policy] Q: What is the coverage for debris removal under Coverage D?
# [Insurance Policy] Q: What are the policy wording for debris removal under Coverage D?
# [TX DOI] Q: What are the rules and regulations for debris removal under Coverage D?
# [TX DOI] Q: What are the insurance related rules and regulations for debris removal under Coverage D?
# [Building Codes] Q: What are the building codes for debris removal under Coverage D?
# [Building Codes] Q: What are the regulations for repairing buildings or other structures under Coverage D?
# [TX DOI] A:
# There are no rules and regulations for debris removal under Coverage D of the Texas Insurance Code.
# [Insurance Policy] A:
# The limit of liability for debris removal under Coverage D is up to 10% of the limit of liability that applies to Coverage A.
# [Building Codes] A:
# Under Coverage D, debris removal is not specifically addressed in the building codes. However, Section 304.3.3 states that dumpsters and containers with an individual capacity of 1.5 cubic yards or more shall not be stored in buildings or placed within 10 feet of combustible walls, openings or combustible roof eave lines. Exceptions to this rule include dumpsters or containers in areas protected by an approved automatic sprinkler system installed throughout in accordance with Section 903.3.1.1 or 903.3.1.2, and storage in a structure of Type I or Type IIA construction located not less than 10 feet from other buildings and used exclusively for dumpster or container storage.
# [TX DOI] A:
# There are no specific insurance related rules and regulations for debris removal under Coverage D. However, Section 2210.208 of the Texas Insurance Code states that a windstorm and hail insurance policy issued by the association for a dwelling must include coverage for wind-driven rain damage, regardless of whether an opening is made by the wind. Additionally, Section 707.002 of the Texas Insurance Code states that a person insured under a property insurance policy must pay any deductible applicable to a first-party claim made under the policy.
# [Insurance Policy] A:
# Under Coverage D, we will pay the reasonable expense for the removal of debris of covered property if a Peril Insured Against that applies to the damaged property causes the loss. This expense is included in the limit of liability that applies to the damaged property. If the amount to be paid for the actual damage to the property plus the debris removal expense is more than the limit of liability for the damaged property, an additional 5% of that limit is available for such expense. We will also pay the reasonable expense, up to $1,000, for the removal from the "residence premises" of your tree (s) felled by the peril of Windstorm or Hail or Weight of Ice, Snow or Sleet, or a neighbor's tree (s) felled by a Peril Insured Against under Coverage C, provided the tree (s) damage (s) a covered structure or does not damage a covered structure but blocks (s) a driveway on the "residence premises" which prevent (s) a "motor vehicle", that is registered for use on public roads or property, from entering or leaving the "residence premises".
# [Building Codes] A:
# Under Coverage D, the regulations for repairing buildings or other structures include examining the construction documents and preparing a finding with regard to the value of the proposed work (R105.3.1.1); establishing permit application time limits and requirements applicable to permit expiration and reactivation, including a review fee for expired permits (R105.5); registering an air conditioning and refrigeration contractor before performing any work regulated by this code (R105.10); providing information for construction in flood hazard areas (R106.1.4); establishing an inspection program for repair or replacement of certain components in individual owned and occupied dwellings (R109.5); allowing for modifications from flood plain management regulations (R112.5); and designing and constructing according to Article 3 (Flood Loads and Hazard Areas) if the work is a substantial improvement as defined in Section R202 (Definitions) (R301.2.4).
# [Insurance Policy] A:
# Under Coverage D, the policy wording for debris removal is:
#
# We will pay your reasonable expense for the removal of: (1) Debris of covered property if a Peril Insured Against that applies to the damaged property causes the loss; or (2) Ash, dust or particles from a volcanic eruption that has caused direct loss to a building or property contained in a building. This expense is included in the limit of liability that applies to the damaged property. If the amount to be paid for the actual damage to the property plus the debris removal expense is more than the limit of liability for the damaged property, an additional 5% of that limit is available for such expense.
#
# We will also pay your reasonable expense, up to $1,000, for the removal from the "residence premises" of: (1) Your tree (s) felled by the peril of Windstorm or Hail or Weight of Ice, Snow or Sleet; or (2) A neighbor's tree (s) felled by a Peril Insured Against under Coverage C; provided the tree (s) damage (s) a covered structure; or (3) Does not damage a covered structure, but blocks (s) a driveway on the "residence premises" which prevent (s) a "motor vehicle", that is registered for use on public roads or property, from entering or leaving the "residence premises".
#
# The limit of liability for debris removal under Coverage D is up to 10% of the limit of liability that applies to Coverage A.
# -----------------
# > Source (Doc id: ff3b47a0-5c3d-4a2e-87e6-258bc036c85a): Sub question: What is the limit of liability for debris removal under Coverage D?
# Response:
# The limit of liability for debris removal under Coverage D is up to 10% of the limit of liability that applies to Coverage A....
#
# > Source (Doc id: 464b08db-6830-4b69-80dc-093bea39e89a): Sub question: What is the coverage for debris removal under Coverage D?
# Response:
# Under Coverage D, we will pay the reasonable expense for the removal of debris of covered property if a Peril Insured Against that applies to the damaged property causes ...
#
# > Source (Doc id: 6912d87d-39e4-4b16-84a8-2503bcde346f): Sub question: What are the policy wording for debris removal under Coverage D?
# Response:
# Under Coverage D, the policy wording for debris removal is:
#
# We will pay your reasonable expense for the removal of: (1) Debris of covered property if a Peril Ins...
#
# > Source (Doc id: 4dd31bdf-67fb-417b-96b2-b387c7a7b27d): Sub question: What are the rules and regulations for debris removal under Coverage D?
# Response:
# There are no rules and regulations for debris removal under Coverage D of the Texas Insurance Code....
#
# > Source (Doc id: 2a903c93-899a-44b2-8bcc-79461356a623): Sub question: What are the insurance related rules and regulations for debris removal under Coverage D?
# Response:
# There are no specific insurance related rules and regulations for debris removal under Coverage D. However, Section 2210.208 of the Texas ...
#
# > Source (Doc id: a18e3591-6f9d-44ca-92b4-eaac06942036): Sub question: What are the building codes for debris removal under Coverage D?
# Response:
# Under Coverage D, debris removal is not specifically addressed in the building codes. However, Section 304.3.3 states that dumpsters and containers with an individ...
#
# > Source (Doc id: 1bca52ae-5bb6-4631-9153-463692beb594): Sub question: What are the regulations for repairing buildings or other structures under Coverage D?
# Response:
# Under Coverage D, the regulations for repairing buildings or other structures include examining the construction documents and preparing a fi...
