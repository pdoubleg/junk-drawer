# %%
import numpy as np
from collections import defaultdict
from sklearn.cluster import AgglomerativeClustering
from joblib import Parallel, delayed
import itertools
import json
from langchain.embeddings import OpenAIEmbeddings
from langchain.llms import OpenAI
from langchain import PromptTemplate, LLMChain



def construct_prompt(prompt_parameters, prompt_template):
    prompt = prompt_template.format(**prompt_parameters)
    return(prompt)

def semantic_clustering(texts, distance_threshold):
    print("Calculating embeddings...")
    embeddings = OpenAIEmbeddings(texts)
    print("done.")

    embeddings = np.array(embeddings)

    hclust_model = AgglomerativeClustering(n_clusters = None, linkage = "average", metric = "cosine", distance_threshold = distance_threshold)
    clustering = hclust_model.fit(embeddings)

    if True:
        clusters = defaultdict(list)
        for text, cluster_label in zip(texts, clustering.labels_):
            clusters[int(cluster_label)].append(text)
        print("Num clusters: " + str(len(clusters.keys())))
        print("Printing top clusters")
        for cluster_id, cluster_texts in clusters.items():
            if len(cluster_texts) > 5:
                print("Cluster id: " + str(cluster_id))
                print("Size: " + str(len(cluster_texts)))
                print(json.dumps(cluster_texts, indent = 4))
                print()

    return(clustering.labels_)


def get_topic_comments_single_review(review, topic, prompt_template):
    prompt_parameters = {
            "review_text" : review["review_text"],
            "topic" : topic
            }
    prompt = construct_prompt(prompt_parameters, prompt_template)
    print(prompt)
    completion = OpenAI(prompt)
    if completion is None:
        comments = []
        return(comments)
    comment_numbers = [x.strip() for x in completion.split(",")]
    parsed_review_text = review["parsed_review_text"]
    print(comment_numbers)
    print(parsed_review_text)
    comments = []
    for x in comment_numbers:
        if x in parsed_review_text:
            comments.append((x, parsed_review_text[x]))            
    
    return(comments)


def get_topic_comments(parsed_reviews, topic):
    """Given parsed version of the text corpus, get all lines that are relevant to topic.
    
    Given a text + topic, we ask GPT to generate line numbers for lines relevant to the topic.
    By working with line numbers instead of the lines, we avoid hallucinations in retrived lines.
    We pull relevant lines from all individual texts across the entire corpus.
     
    :param parsed_reviews: The text corpus as a list. Each entry in the list is a dict.
        Each dict must have the key 'review_text', which stores the individual text
        Each dict must have the key 'parsed_review_text', which stores the parsed individual text.
    :param topic: the topic of interest
    :type reviews: list
    :type topic: str
    :returns: list of relevant lines. Each entry is of form (line_number, line_text)
    :rtype: list
    """
    
    
    prompt_template_1 = """{review_text}

        The above is a numbered list of comments about minecraft.
        Based on the above comments answer the below question.


        What comments have suggestions to improve {topic}.
        List their comment numbers as a comma seperated list.

        Comment numbers:
        """

    print("Getting comments from single reviews...")
    n_jobs = 4
    print("Starting " + str(n_jobs) + " parallel jobs.")
    suggestions = Parallel(n_jobs = n_jobs)(delayed(get_topic_comments_single_review)(review, topic, prompt_template_1) for review in parsed_reviews)
    print(suggestions)
    #suggestions are of form (number, quoted_comment)
    suggestions = list(itertools.chain(*suggestions))
    print("Done.")
    
    return(suggestions)


def summarize_cluster(topic, comments):
    """Given a topic and lines that are relevant to the topic, summarize the lines
    
    :param topic: the topic of interest
    :param comments: list of relevant lines. Each entry is of form (line_number, line_text)
    :type topic: string
    :type comments: list
    :returns: summary of lines
    :rtype: string
    """
    
    prompt_template = """{comments_text}

The above is a list of comments about {topic} in a minecraft chat.
Based on the above comments answer the below question.


Summarize the comments.
Summarize top 3 suggestions to improve {topic}. If there are no suggestions, mention 'no suggestions'.

"""
    
    comments_text = ""
    for comment_number, comment_text in comments:
        comments_text += "\n" + comment_text
        
    prompt_parameters = {
            "comments_text" : comments_text,
            "topic" : topic
            }
    prompt = OpenAI(prompt_parameters, prompt_template)
    print(prompt)
    completion = OpenAI(prompt)
    
    return(completion)

def get_topic_summaries_with_references(topic, comments, top_cluster_size_threshold):
    """
    Given a topic and lines that are relevant to the topic, extract dominant clusters of lines and summarize each cluster.
    
    comments contains the text of lines that are relevant to topic.
    Use semantic clustering on these lines to get clusters that are:
    1. Semantically highly similar
    2. Have a significant size (number of lines in the cluster > top_cluster_size_threshold)
    Clusters that satisfy these two properties are called dominant clusters, and capture
    the major information in the lines.
    The lines that dont belong to a dominant cluster are discarded before summary.
    Next, we summarize each dominant cluster and include the lines of that cluster as references for that summary.
    Since the dominant cluster is quite homogenous, we will get a good summary.
    Since the lines were extracted from the corpus via line numbers, they are reproduced verbatim here
    and avoid hallucinations in the references.
    Hence we good focussed summary of the dominant points with verbatim / non-hallucinated references.
    
    :param topic: the topic of interest
    :param comments: list of relevant lines. Each entry is of form (line_number, line_text)
    :param top_cluster_size_threshold: minimum size for a cluster to be a dominant cluster
    :type topic: string
    :type comments: list
    :type top_cluster_size_threshold: int
    :returns: Dict of summaries. Keys are the cluster ids, values are the summaries of that cluster.
        The cluster summaries are dicts. Keys are comments, summary.
        The value of comments are the lines in that cluster.
        And summary is the summary of those lines (clusterwise summary).
    :rtype: dict
    """
    
    # 1) Calculate embeddings
    print("Calculating embeddings...")
    embeddings_model = OpenAIEmbeddings()
    embeddings = embeddings_model.embed_documents(texts=comments)
    print("done.")

    embeddings = np.array(embeddings)
    print(embeddings.shape)

    # 3) Do hierarchical clustering
    distance_threshold = 0.2
    hclust_model = AgglomerativeClustering(n_clusters = None, linkage = "average",
                                           metric = "cosine", distance_threshold = distance_threshold)
    clustering = hclust_model.fit(embeddings)

    # 4) Massage into clusters of comments
    clusters = defaultdict(list)
    for x, cluster_label in zip(comments, clustering.labels_):
        comment_number, comment_text = x
        clusters[int(cluster_label)].append((comment_number, comment_text))
    print("Num clusters: " + str(len(clusters.keys())))

    # 5) Select the top clusters and summarize them.
    top_clusters = {}
    for cluster_label, comments in clusters.items():
        num_comments_in_cluster = len(comments)
        if num_comments_in_cluster > top_cluster_size_threshold:
            top_cluster_comments = comments
            top_cluster_summary = summarize_cluster(topic, comments)
            top_cluster_info = {"comments" : top_cluster_comments,
                               "summary" : top_cluster_summary}
            top_clusters[cluster_label] = top_cluster_info
    print("Num top clusters: " + str(len(top_clusters.keys())))
            
    return(top_clusters)

def print_topic_summaries_with_references(topic, topic_summaries_with_references):
    """Pretty print the summaries with references of the topic.
    
    :param topic: the topic
    :param topic_summaries_with_references: Dict of summaries. Keys are the cluster ids, values are the summaries of that cluster.
        The cluster summaries are dicts. Keys are comments, summary.
        The value of comments are the lines in that cluster.
        And summary is the summary of those lines (clusterwise summary).
    :type topic: str
    :type topic_summaries_with_references: dict
    """

    print("Topic is: " + topic)
    for cluster_label, summary_with_references in topic_summaries_with_references.items():
        comments = summary_with_references["comments"]
        summary = summary_with_references["summary"]
        print("\nSummary with references:\n")
        print("Summary: \n" + summary + "\n")
        print("References: \n")
        for comment_number, comment_text in comments:
            print(comment_number + ":" + comment_text)

# %%
from src.semantic_clustering import semantic_clustering
import pandas as pd

# %%
df = pd.read_csv("../data/data_science_jobs_indeed_usa.csv")

# %%
print(df.shape)
df.head()
# Out:
# (1200, 10)
#    Unnamed: 0                                              Title  \
# 0           0                                     Data Scientist
# 1           1                                   Business Analyst
# 2           2  IT Business Intelligence Developer (FT) Remote...
# 3           3                                      Data Engineer
# 4           4                Network Administrator/dba developer
#
#                    Company                              Location  Rating  \
# 0            Driven Brands                           Benicia, CA     2.4
# 1         Sabot Consulting                                Remote     NaN
# 2            Ballad Health             Remote in Blountville, TN     3.0
# 3  Longevity Holdings Inc.  Remote in Minneapolis-Saint Paul, MN     NaN
# 4             WKI Kenworth                     Wichita, KS 67219     NaN
#
#                         Date                     Salary  \
# 0   PostedPosted 26 days ago                        NaN
# 1    PostedPosted 4 days ago         $80 - $120 an hour
# 2  PostedPosted 30+ days ago                        NaN
# 3    PostedPosted 3 days ago  $90,000 - $110,000 a year
# 4  EmployerActive 2 days ago   $50,000 - $70,000 a year
#
#                                          Description  \
# 0  You’ll be working alongside a team of eight an...
# 1  Preferred candidates will have prior experienc...
# 2     Job Details Apply Save Print this job Email a…
# 3  Incorporate core data management competencies ...
# 4  The Network Administrator provides 2nd level e...
#
#                                                Links  \
# 0  https://www.indeed.com/rc/clk?jk=74d176d595225...
# 1  https://www.indeed.com/rc/clk?jk=f662b2efb509b...
# 2  https://www.indeed.com/rc/clk?jk=58612836c63b8...
# 3  https://www.indeed.com/company/TwentyFirst/job...
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
#
#                                         Descriptions
# 0  We invite you to join us at Driven Brands!\nHe...
# 1  Sabot Consulting (Sabot) is a management consu...
# 2  Job Details\nApply\nSave\nPrint this job\nEmai...
# 3  Position: Data Engineer\nLocation: MN\nAs a Da...
# 4  Full Job Description\nThe Network Administrato...

# %%
text = df['Description']

# %%
print(text[0])
# Out:
# You’ll be working alongside a team of eight analysts & data scientists - collaborating to design datasets, develop analytical models & provide insights.

# %%
test = semantic_clustering(texts=text, distance_threshold=0.2)
# Out:
# Calculating embeddings...
# done.
# Num clusters: 67
# Printing top clusters
# Cluster id: 6
# Size: 721
# [
#     "You\u2019ll be working alongside a team of eight analysts & data scientists - collaborating to design datasets, develop analytical models & provide insights.",
#     "Preferred candidates will have prior experience in implementing Cloud-hosted business process migration in Software as a Service (SAAS) implementations\u2026",
#     "Incorporate core data management competencies including data governance, data security, and data quality.\nPartner closely with our data scientists to ensure the\u2026",
#     "Ensure adaption of data science product with the business users to drive outcome and patient impact.\nAbility to work with marketing agencies to define the data\u2026",
#     "5+ years of relevant experience in report development, data science, business analytics, business intelligence, or comparable data engineering role, including\u2026",
#     "Stay aware of emerging data science techniques, technologies, and applications.\nHire, train, retain and challenge best-in-class data science and analytics\u2026",
#     "5+ years management experience building and leading data science teams.\n10+ years of technical experience in a data science role or equivalent.",
#     "Should have strong data analysis.\nProven experience in Design & Implementation of end-end data pipelines.\nProblem analysis and troubleshooting complex & \u201clarge\u2026",
#     "Must have experience working in Data Lakes with in Oracle or SQL.\nAnalysis, pulling data from a data lake.\nExperience working with Oracle 12C.",
#     "10+ years of experience in developing and implementing data science techniques.\nStrong knowledge of the fundamental statistical and AI underpinnings of data\u2026",
#     "3+ years of experience in managing and mentoring data science, data engineering, and analytics teams in a technology company.",
#     "Keen eye for methodological and data nuances.\nUsing state of the art AI tools, DS platforms, ML libraries, and optimization tools, we leverage internal,\u2026",
#     "Ideally, you have experience as a team leader on a data science team where you were responsible for overseeing all aspects of data science technical projects,\u2026",
#     "Provide high-level data and AI/ML subject matter expertise to inform strategic communications and project planning.\nThe Ideal Candidate Must Have: *.",
#     "Collaborate with central team data science, insight and CRM teams to employ insight, segmentations and models to improve personalization and targeting of CRM\u2026",
#     "Collaborate with members, project/program managers, and other teams to turn data into critical information and knowledge that can be used to make sound\u2026",
#     "Experience with traditional data warehouse data structures.\nExperience with data pipelines using Confluent Kafka.\n10+ years of related experience.",
#     "The Data Scientist will be responsible for modeling complex scientific clinical data, discovering business/clinical/health insights and identifying\u2026",
#     "Proficiency with data mining and machine learning.\nYou have a deep understanding of and experience in modern machine learning theories, Transformers, and Large\u2026",
#     "Analyze product data to identify problems and ideate product features and process enhancements.\nBuild controls, processes, and systems to ensure SLAs are met to\u2026",
#     "Experience with interactive machine learning (eg. active learning, reinforcement learning, machine teaching) a plus but not required.",
#     "Manage and scale data pipelines from internal and external data sources to support new product launches and drive data quality across data products.",
#     "Understanding of various advanced analytical and machine learning methods.\nExcellent understanding of machine learning frameworks (Keras/Tensorflow/PyTorch etc.\u2026",
#     "Create analytical reports/dashboards to monitor data issues and business processes.\nAs a Business Intelligence Developer, you will be responsible for creating\u2026",
#     "Create analytical reports/dashboards to monitor data issues and business processes.\nAs a Business Intelligence Developer, you will be responsible for creating\u2026",
#     "2+ years of business intelligence & data warehousing experience.\nYou will create/develop complex reports and dashboards within our business intelligence\u2026",
#     "7+ years of overall software development and/or database engineering experience required.\n2+ years of hands-on development experience with event based streaming\u2026",
#     "3+ years of experience in performing data analysis, data ingestion and data integration.\n2+ years of experience with schema design, data modeling and SQL\u2026",
#     "Support various business data needs through creating dashboards, extracting/formatting raw data, etc.\nManage data quality assurance processes:",
#     "Discover and recommend new data sources to complement existing data.\nThis position manages direct reports and multiple consultants/contractors including data\u2026",
#     "We make data science workflows repeatable, scalable, and observable while reducing toil and increasing release velocity.",
#     "Design, develop, test, and deploy data analytics solutions to solve business challenges.\nCandidates must reside in NY and be eligible to work in the United\u2026",
#     "7+ years\u2019 experience in analytics and data science.\nFamiliarity with data exploration and data visualization tools, like Tableau, Datorama, etc.",
#     "Bring a rigorous statistical, data-driven approach to all data science decisions.\nAt least eight years of data science or relevant experience.",
#     "This team member collaborates with Data Scientists to design tools to train machine learning models using data from across the enterprise and deploy machine\u2026",
#     "Leverage numerous data sources to identify opportunities for improved efficiency and targeting.\nThis position combines data analytics and strategic guidance of\u2026",
#     "Experience querying, analyzing, and reporting large data-sets to answer complex business questions.\nBe a SME both technically and functionally, for Cash App\u2026",
#     "We are looking for a highly capable machine learning engineer to optimize our machine learning systems.\nA first-class machine learning engineer will be someone\u2026",
#     "Collaborate with data science, data engineering, and research teams to contribute to data methodologies, roadmap planning and understand nuances to our data.",
#     "Reframe business and newsroom objectives as machine learning tasks that can deliver actionable insights, accurate predictions, and effective optimization.",
#     "Developing and managing business intelligence solutions for the organization.\nProviding reports through office applications to improve business processes.",
#     "Work with IT teams to support data collection, integration, storage, access, analysis, and retention requirements based on the surveillance data collected.",
#     "Proficient in working with large data sets and pipelines.\nSCALA, SPARK, SQL, HADOOP, AWS, HIVE, Spark SQL, HIVE QL, CICD (Continuous Integration/Continuous\u2026",
#     "Collaborate with software and reliability engineers to automate repeatable data tasks.\nCollaborate with software developers, other data engineers, and database\u2026",
#     "Industry or research experience in data analytics, machine learning, and software development.\nExtend the capabilities of our machine intelligence, natural\u2026",
#     "They are excited by the idea of learning new concepts ranging from embedded integration, computer vision, and machine learning.",
#     "8+ years of working experience in data science and data analytics positions.\nCollaborate with data engineers to understand underlying data architecture, and to\u2026",
#     "MS in data science, economics, computer science, or a quantitative/engineering field.\nYou will bring experience spanning analytics, economics, and data science\u2026",
#     "Partner with various data teams to set up data extraction for business requirements.\nBuild required infrastructure for optimal extraction, transformation and\u2026",
#     "Experience with data profiling and data quality analysis.\nDesigns, deploys and supports data acquisition and data integration solutions from source systems to\u2026",
#     "Oversee data science projects through the project lifecycle, from scoping through to implementation.\nMS/PhD and minimum 7 years of data science/quantitative\u2026",
#     "We have an immediate opening for a machine learning engineer with experience in object detection, deep learning, and modeling.\nPython Flask: 1 year (Required).",
#     "Establish best practices for data science workflows.\nManage large-scale data science projects that leverage data transformation and machine learning models.",
#     "You will be a member of a multidisciplinary team of data scientists, engineers, and clinicians tackling complex problems in a data-driven and collaborative way.",
#     "Design and build modern data pipelines, data streams, and data service Application Programming Interfaces (APIs).\nImplement effective metrics and monitoring.",
#     "Develop and deploy machine learning models for ad recommendation (CTR prediction, Personalization and user segmentation, Exploration/Exploitation Algos).",
#     "Experience with data profiling and data quality analysis.\nDesigns, deploys and supports data acquisition and data integration solutions from source systems to\u2026",
#     "Experience deploying machine learning models to production environments.\nExperience with machine learning frameworks such as PyTorch or TensorFlow/Keras.",
#     "Help architect data solutions/frameworks and define data models for the underlying data warehouse and data marts.\nDevelop UAT plans and conduct QA.",
#     "Deployment of the data science services at a large scale.\nProductizing the machine learning problems.\nDeep Learning models and its deployments.",
#     "Advocate, evangelize and implement modern data science practices.\nReflects clear data and actionable insights.\nDriven direction that is actionable.",
#     "Serve as the main point of contact for data science.\nFamiliarity with data science/machine learning algorithms (e.g. time series analysis, HMM, Deep Learning\u2026",
#     "Identify and execute appropriate scientific methods (experimentation, causal inference, regression methods, machine learning, etc.) to create impactful insights\u2026",
#     "Solve some of the most challenging problems in natural language processing, machine learning, and information retrieval including topical classification,\u2026",
#     "The successful candidate will work with high level BI-ETL developers to convert legacy Teradata BTEQ scripts into Informatica mappings/workflows that will\u2026",
#     "Write business requirements and support our best-in-class data engineering team as they bring them to life.\nBachelors or Master\u2019s degree.",
#     "Design and develop enterprise business intelligence and reporting solutions using Tableau.\nTableau is a new technology to NIH and therefore your role is key in\u2026",
#     "As the data science leader, you'll shape how 'all things' data and data science contribute to Duolingo's strategy.\nExperience with analyzing large datasets.",
#     "As a part of the larger Data Science & Engineering department, the User Experiences ML & CI team produces ML & CI models used to understand the\u2026",
#     "This individual will be responsible for aligning the models with the university\u2019s overall machine learning strategy and road map.\nAnalysis- 50% of the time.",
#     "Experience leading end-to-end data science project implementation.\nThis role will work closely with Product, Engineering and Business Development leadership to\u2026",
#     "8 years of experience in predictive modeling, large data analysis and computer science.\nKnowledge and application of Data Science principals and experience with\u2026",
#     "Designs, develops, and maintains various business intelligence applications (reports, dashboards, scorecards).\nAdvanced knowledge of T-SQL is a requirement.",
#     "This position will report to the director of business intelligence and will be responsible for designing, developing, and supporting our organizations data\u2026",
#     "Mastery in business intelligence and data warehousing concepts and methodologies.\nBroad understanding of multiple existing and next generation business\u2026",
#     "Experience performing data analysis and data exploration.\nExperience building automated data pipelines.\nExperience with big data frameworks (i.e. Hadoop and\u2026",
#     "You know understanding the data is often the key to great data science.\nYou have hands-on experience developing data science solutions using open-source tools\u2026",
#     "Enhance company\u2019s machine learning framework, debug and correct data assumption through machine learning.\nAt least 3 years\u2019 experience manipulating data sets\u2026",
#     "Build highly-scalable classifiers, tools, models and algorithms leveraging cutting-edge machine learning and computer vision technologies.",
#     "Collaborate closely with experimental scientists to ensure that data is generated and used effectively.\nRecruit, lead, mentor, and develop a talented team of\u2026",
#     "Show efficiency in handling data - tracking data lineage, ensuring data quality, and improving discoverability of data.\nSkilled in writing and optimizing SQL.",
#     "Experience supporting sales and business development.\nSupport business intelligence solution architecture, design, development, implementation, and\u2026",
#     "Leads data science development, contributes to problem-solving, and collaborates internally and externally on various research projects.",
#     "Experience in building/Optimising data modules and pipelines.\nStrong experience in Big data technologies Spark ,Hive, Hadoop platforms.",
#     "Work independently and as a member of a multi-functional, dynamic, multi-disciplinary team to setup and manage dynamic data visualizations and dashboards using\u2026",
#     "Hire, inspire, and grow high-performing data scientists and analysts.\nYour team will apply strong analytical rigor to evaluate ideas, dissect problems, build\u2026",
#     "Contribute towards advancing the Data Science discipline at 2U, including driving data best practices such as improving and automating analytical processes,\u2026",
#     "Experience in developing advanced data science and ML infrastructure and systems.\nMLB is hiring a Director, Data Science to guide and oversee the best practices\u2026",
#     "Experience in analyzing data to draw business-relevant conclusions and in data visualization techniques and tools.\n5 years minimum of relevant experience.",
#     "Strong experience with data science project life cycle and delivery methodology.\nDegree in a quantitative field, such as data science, statistics, mathematics,\u2026",
#     "Developing and maintaining formal documentation that describes data and data structures including data modelling.\nExperience in high volume data environments.",
#     "Strong Python and R skills.\nExperience using cloud technology - AWS/Snowflake/S3 (anyone).\nExperience in Data Analytics and Machine Learning and NLP.",
#     "Keen on learning about various tools and techniques for data wrangling and pipelining.\nHands-on experience in deep learning frameworks such as TensorFlow and\u2026",
#     "Work with internal customers, ML engineers, and data scientists in Core org, to understand and solve development velocity pain points.",
#     "Experience with SQL profiling, performance tuning and data ingestion into Data Warehouses.\nAdvanced experience with AWS or other cloud providers (Elastic\u2026",
#     "Provide guidance and technical support to departments regarding data analytics, business measures, and reporting.",
#     "You'll work closely with other data scientists and business partners in identifying and defining data science projects, building machine learning algorithms and\u2026",
#     "4+ years of professional software development experience with advanced machine learning or statistical and numerical optimization methods.",
#     "This work will include tapping into big data insights by collaborating with other data scientists \u2014 individuals with interdisciplinary backgrounds that include\u2026",
#     "Work closely with internal and external team members to develop and build self-service capabilities, and automation, to enable our internal customers to move\u2026",
#     "Work alongside and support a talented team of data engineers.\nBe an expert of stitching and calibrating data across various data sources.",
#     "Develop hosting platform for machine learning models.\nSupervise the scaling and management of the machine learning modeling ecosystem.",
#     "The Data Scientist will be responsible for modeling complex scientific clinical data, discovering business/clinical/health insights and identifying\u2026",
#     "Exposure to machine learning methodology and best practices.\nFamiliar with CI/CD pipelines for machine learnings.",
#     "Experience putting machine learning models into production.\nHas strong fundamentals in machine learning and statistics evidenced by a track record of\u2026",
#     "Bachelor\u2019s Degree in computer science, data science, business administration, or equivalent discipline is required.\nAbility to make complex concepts simple.",
#     "Proficient with modern big data technologies and CI/CD frameworks.\nTrack record of delivering data-driven products, insights, and influencing product and\u2026",
#     "Bachelor\u2019s Degree or equivalent work experience focused on data analytics, data science, mathematics, actuarial or computer science.",
#     "Work closely with other data analysts and across functions to help produce all required design specifications and ensure that data solutions work together and\u2026",
#     "10 years of experience in IT career implementing enterprise data solutions leveraging modern data technologies required.",
#     "Bachelor\u2019s Degree in computer science, data science, business administration, or equivalent discipline is required.\nAbility to make complex concepts simple.",
#     "Strong understanding of data warehousing and data modeling techniques.\nStrong data engineering skills on GCP cloud platforms.",
#     "Work with data scientists and associate data scientists to ensure the correct data sets, calculations and analytic method being employed to solve a given\u2026",
#     "Masters or Ph. D. in machine learning, or 5 plus years of experience in developing image processing software.\nIn progress partnership with industry.",
#     "The team utilizes open-source, AWS Cloud, and Big Data technologies, agile project management practices, and modern DevSecOps delivery to provide the business\u2026",
#     "Data analysis, data modelling, data integration, data warehousing and database design.\nExperience with streaming data processing.",
#     "5+ years of experience in data science-related roles.\nCollaborates with business leaders and contributes to long-term data science and business roadmap.",
#     "A bachelor\u2019s degree in business or related field or an MBA.\nA minimum of 1 years of experience in business analysis or a related field.",
#     "Expertise in the use of complex data science or optimization analysis.\nLead the use of complex data science or optimization analysis for specific business\u2026",
#     "This person will be responsible for developing reports, dashboards, ETL, and analytics.\n_Reasonable accommodations will be made to enable individuals with\u2026",
#     "Business intelligence: 5 years (Preferred).\nBusiness Intelligence - they are working on an enterprise project (1 year in maturity) to centralize reporting for\u2026",
#     "No stranger to translating business challenges into data analytics problems.\nFamiliarity with leveraging APIs for data extraction purposes a plus.",
#     "Relevant experience must be in one or more of the following: designing/implementing machine learning, data mining, advanced analytical algorithms, programming,\u2026",
#     "Apply data analysis, data mining to understand and solve business problems.\n4+ years of experience in analytical role (analysis, information science, data\u2026",
#     "Hands on experience developing video analytics, machine vision-based applications.\nUnderstanding of machine learning lifecycle - train, test, validate.",
#     "3+ years of proven experience as a data engineer, software developer, or similar, building data infrastructure from the ground up.",
#     "Programs metrics and reports in a data visualization tool/analyst software (e.g., Power BI, Spotfire).\nAbility to independently develop innovative and complex\u2026",
#     "Lead and develop a talented team of software engineers and data scientists, who are responsible for building the product, including data collection, data\u2026",
#     "This team's key partners include other product teams, finance, data science, and other teams within data engineering.",
#     "Data ETL processes: 3 years (Required).\nCollaborate with data architects, modelers and IT team members on project goals.",
#     "Experience with a major machine learning framework (e.g. TensorFlow, MXNet, Caffe2, PyTorch).\nYou will also participate in the development of the novel machine\u2026",
#     "The role will involve working with Research Scientists in analyzing complex data, generating insights, and creating solutions as needed across a variety of\u2026",
#     "Promote sound data science practices including pipeline development, source control, and performance monitoring.\nData science: 8 years (Preferred).",
#     "Familiarity with machine learning algorithms applicable to model data.\nThe position calls for research scientists/computational protein engineers.",
#     "Strong organization skills to manage multiple timelines and complete tasks quickly within timeline and budget constraints.\nFull Stack Developer Daily Tasks*.",
#     "Displays a high degree of proficiency in data management and data analytics methodologies and technologies including but not limited to - understanding of\u2026",
#     "In partnership with business stakeholders across the company, frame data science initiatives to establish business strategies and solve business challenges such\u2026",
#     "Collaborate with researchers on projects related to machine learning, artificial intelligence, and computer vision.",
#     "Oversee the internal data resources and consulting partners leveraging the data science tool sets.\nYou have a Bachelor\u2019s degree OR equivalent experience (4+\u2026",
#     "Research developments and trends in business intelligence including new products, services and technological advances.\nProficient in MS Office Suite.",
#     "Guide and create appropriate data solutions (dashboards, reports, business intelligence tools, etc.).\nAssist with business analysis and workflow documentation\u2026",
#     "Collaborate and influence team resourcing including engineering, data engineering, customer engagement, and product managers to ensure successful execution.",
#     "Design, develop, and maintain business intelligence solutions (dashboards and reports) to provide user-friendly and valuable data insights.",
#     "Expert/Master in common families of machine learning models, feature engineering, feature selection techniques, and tuning of machine learning models.",
#     "Working knowledge of database methodologies and workflow process analysis.\n0-2 years related database development or programming experience.",
#     "\uf0b7 6+ years experience engineering software and data platforms / enterprise- scale data warehouses, preferably with knowledge of open source Apache.",
#     "Collaborate with engineers, product managers, data scientists and analysts on mission critical data needs to build world-class datasets.",
#     "Hands-on quantitative experience to include data mining, predictive modeling, machine learning, statistical programming, working with both structured and\u2026",
#     "Help build out capabilities that will drive business decisions.\nWork on a large portfolio of globally distributed developer teams to deliver products and\u2026",
#     "Passionate about the research and contribution of data science innovations into a software product.\nAt least 3-5 years of experience in data science or a\u2026",
#     "Demonstrated ability in Business intelligence, software development, testing and maintenance focused on Jira and Power BI.\nJob Types: Full-time, Contract.",
#     "Our data science team leverages large volumes of data to develop powerful sciences using cutting edge machine learning and mathematical techniques to improve\u2026",
#     "Experience in Architect, design and implementing scalable ETL and data processing systems to handle the big data ecosystem including data collection, processing\u2026",
#     "Evangelize the practice of data science and rigor around statistical concepts and practices.\nDrives projects with hands-on data science, analysis, or\u2026",
#     "Publications at major machine learning conferences or in major scientific journals.\nOptimize and deploy novel machine learning models for RNA structure\u2026",
#     "Experience working with machine learning algorithms to solve classification and clustering problems, perform information retrieval from unstructured and semi\u2026",
#     "Familiarity with data visualization tools.\nComfortable pulling and manipulating data using SQL.\nParticipates in and oversees the Data Science team in analyzing\u2026",
#     "2+ years of industry experience of applying machine learning at scale.\nYou will design, implement and integrate the next generation of Machine Learning\u2026",
#     "At least 3 years of experience as a software engineer or machine learning engineer.\nFamiliarity with Tensorflow, BERT, embeddings, deep learning, text parsing,\u2026",
#     "Basic understanding and willingness to learn machine learning algorithms and concepts.\nWe augment economic evaluation with AI and machine learning tools to\u2026",
#     "Partner with IT and the Analytic Community in driving the assessment and cataloging of data sources for customer touchpoints across the enterprise; work with IT\u2026",
#     "Five (5) years of experience as a data scientist in a large financial firm.\nProvide a short statement on a recent quantitative analysis project you recently\u2026",
#     "Lead the customer data strategy across data science, engineering, and analytics, driving alignment with senior leadership team.",
#     "The Business Intelligence Analyst is responsible for analyzing and reviewing data that is collected in our current and future products and services.",
#     "Experience putting machine learning models into production.\nHas strong fundamentals in machine learning and statistics evidenced by a track record of\u2026",
#     "Experience applying various machine learning techniques and understanding the key parameters that affect their performance.\n12 weeks of Paid Parental Leave.",
#     "He should have experience building and optimizing \u2018big data\u2019 data pipelines, architectures and data sets.\nBuild processes supporting data transformation, data\u2026",
#     "Experience using statistical computer languages (Python, SQL) to manipulate data and draw insights from large data sets.\nBachelor\u2019s degree in a related field.",
#     "It takes a scientist to analyze, evaluate, and maintain data so that it can be used to build, validate, and deploy _machine learning (ML) models_ that help SAIF\u2026",
#     "2 years of experience leading complex data science projects from conception to execution.\nConsult with potential customers and corporate business executives,\u2026",
#     "Experience with coding DAGs in Airflow.\nGood experience in AWS Glue, Glue Catalog and Rest APIs.",
#     "Evaluates strategic business unit market performance through the use of benchmark data.\nParticipates in the business intelligence (BI) solution development life\u2026",
#     "Help build out capabilities that will drive business decisions.\nWork on a large portfolio of globally distributed developer teams to deliver products and\u2026",
#     "We're looking for machine learning engineers with a background in reinforcement learning.\nPrimordial Labs is developing Scipio, a tactical AI assistant for\u2026",
#     "Experience in leading, managing and building data science teams.\nExperience using statistics and data science to solve complex business problems.",
#     "Have led teams of 25+ engineers and have experience managing managers,.\nPartner with our recruiting team to attract a diverse team of exceptional engineers,.",
#     "Provides production support for business intelligence solutions.\nIndependently work closely with end users to understand and translate business needs to create\u2026",
#     "2 years of experience leading complex data science projects from conception to execution.\nConsult with potential customers and corporate business executives,\u2026",
#     "Support analytics, engineering, BI and data science work hands-on from time-to-time.\nSolve business problem using data driven solution \u2013 understand problem\u2026",
#     "3-5 years experience in data analytics.\nIdentify, analyze, and interpret trends or patterns in complex data sets.",
#     "Experience with data profiling and data quality analysis.\nDesigns, deploys and supports data acquisition and data integration solutions from source systems to\u2026",
#     "Support discovery of business problems \u2022Analyze and interoperate new sources of data \u2022Perform ad-hoc and reoccurring statistical analyses \u2022Work with data\u2026",
#     "3+ years experience as a data engineer or data analyst.\nConnect new systems to the data platform as needed.\nProvide training and support to users in using our\u2026",
#     "Ensures that the use of business intelligence applications enhance clinical & business decision-making capabilities.\nDay Shift, 8:30 am - 5:00 pm.",
#     "Statistical data analysis: 3 years (Preferred).\nDesired Skills: \\*5+ years exp with SQL(preferred), SAS(preferred) \\*Exp working with enterprise level business\u2026",
#     "Depth of experience leading business intelligence organizations serving highly diverse and data hungry business partners in companies deriving competitive\u2026",
#     "Experience in one or more of the following areas: applied machine learning, machine learning infrastructure, large-scale recommendation system, market-facing\u2026",
#     "1 year of experience using statistical computer language R, Python, or SQL to manipulate data and draw insights from large data sets.",
#     "Build/integrate business intelligence and analytics tools that utilise available data pipelines to provide actionable insights for the business, our customers\u2026",
#     "Collaborate closely with technical database, business, and quality assurance teams.\nThe BI Developer will work with the data team and business analysts to\u2026",
#     "Advanced data science and mathematical skills (e.g. PhD in computational modeling, machine learning, statistics, computer science).",
#     "Preferred candidates will have prior experience in implementing Cloud-hosted business process migration in Software as a Service (SAAS) implementations\u2026",
#     "Deep understanding of and proven ability to apply data science and machine learning concepts such as deep learning, CNN (in particular computer vision),\u2026",
#     "Knowledge and strong interest in AI innovation trends, and advanced data analytics software applications.\nTerms of Hire: Full Time.",
#     "Strong knowledge of statistics and machine learning.\nMachine learning: 1 year (Preferred).\nPrevious experience with at least two deep learning frameworks.",
#     "Experience with scalable machine learning on GPUs, including applications to large datasets.\nWork with computational chemists to develop structure-based machine\u2026",
#     "You will work in close collaboration with data scientists on the Consumer Data Science (CDS) teams.\nYou will manage cross-functional product management squads\u2026",
#     "As a Lead, you will be leading and growing a team of Data Scientists and Data Analysts working on our data warehouse and helping each department with their data\u2026",
#     "Programs metrics and reports in a data visualization tool/analyst software (e.g., Power BI, Spotfire).\nAbility to independently develop innovative and complex\u2026",
#     "Experience building and maintaining a data analytics platform.\nDesign, build and maintain a robust data pipeline and warehouse.",
#     "Have a solid understanding of data warehouses, data lakes and business intelligence tools.\nDevelop custom data infrastructure when not available off-the-shelf\u2026",
#     "You have hands-on experience developing data science solutions using open-source tools and cloud computing platforms.",
#     "Experience creating and leading a data science/business intelligence function.\nOwn the overall design and support of the analytical reporting ecosystem,\u2026",
#     "Deep understanding of and proven ability to apply data science and machine learning concepts such as deep learning, CNN (in particular computer vision),\u2026",
#     "In this highly technical, fast-paced, and challenging position, you'll collaborate with multidisciplinary team members to provide the very best care for our\u2026",
#     "Awareness of how to develop and automate scalable machine learning pipelines in cloud ecosystems (Azure/AWS/GCP).\nLife, AD&D, and disability insurance.",
#     "Proven working experience as a Database administrator.\nFamiliarity with database design, documentation and coding.\nFamiliarity with programming languages API.",
#     "Technical. Experience working with customer data platforms, event-level data, ML & feature engineering pipelines.\nA hybrid work model for all corporate roles.",
#     "Teach the broader data science team new tools and techniques.\nWork with external data providers to test new data and develop strategies for inclusion into the\u2026",
#     "Experience with data science, data engineering, and MLOps workflows in a traditional on-prem, hybrid cloud, or public cloud environment is highly desirable as\u2026",
#     "Monitor data warehouse infrastructure and business intelligence scheduled processes and identify opportunities to make enhancements.",
#     "Proficiency with multiple ETL and business analysis systems.\nWith a focus on continually enhancing our business, you compile accurate and punctual reports using\u2026",
#     "Have in-depth knowledge of data engineering and building data pipelines with a minimum of 5 years of experience in data engineering, data science or analytical\u2026",
#     "Experienced with advanced machine learning methods.\nHave 3+ years of experience being a major machine learning contributor at a top company, hedge fund, or\u2026",
#     "Work closely with analysts, traders, developers, and other data scientists to develop powerful analysis, models, and analytical solutions.",
#     "Experience working with large data sets, advanced statistics, and predictive models.\nDemonstrated experience integrating and mining large data sets to generate\u2026",
#     "Experience with data science, data engineering, and MLOps workflows in a traditional on-prem, hybrid cloud, or public cloud environment is highly desirable as\u2026",
#     "Tasks to extract data from databases and orchestrate these.\nExperience in designing and executing solutions for complex business problems involving large scale\u2026",
#     "10+ years experience in data science, data analytics, and machine learning.\nDevelop our data science strategy and vision.",
#     "For our experts in machine learning, data science, applications, and technology integration, cracking the insurance industry\u2019s previously \u2018impossible\u2019 big data\u2026",
#     "Acquire data from primary or secondary data sources and maintain databases/data systems.\nMaintain and improved existing data visualizations, data pipelines and\u2026",
#     "Advanced degree majoring in data science, epidemiology, public health, statistics, computer science or related field a plus.\nAttention to detail and accuracy.",
#     "Ensures that the use of business intelligence applications enhance clinical & business decision-making capabilities.\nDay Shift, 8:30 am - 5:00 pm.",
#     "Influence our data science strategy and vision.\nExperience guiding and growing a team of data scientists to achieve driven business goals using innovating data\u2026",
#     "Drive better talent decision making through story-telling with data.\n2+ Years working as a data scientist or applied quantitative researcher.",
#     "Prior experience supporting data scientists or machine learning engineers in a Project Management capacity; understanding of how traditional agile methodologies\u2026",
#     "Research and strategize data analytical solutions to transform envisioned 5G features challenges.\nDeploy integrated data analytics framework (application-level,\u2026",
#     "Strong attention to detail with the ability to interpret raw data and assess large data sets for data integrity to effectively identify and treat outliers and\u2026",
#     "Plan, develop, and maintain core data science functionality (including artificial intelligence, machine learning, and custom data analysis functionality) in\u2026",
#     "Experience with imaging data (medical image data preferred).\nThe Lead Data Engineer is responsible for managing all imaging data, metadata and tools for\u2026",
#     "Lead the technical strategy of the data science team.\nPrevious experience as a manager of data scientists and ML engineers.\nDrive for impact and accountability.",
#     "Comprehensive knowledge of data platform architecture, data modeling, database optimization, data management practices and processes.",
#     "8+ years of professional experience working in data science and analytics.\nExperience leading and growing a high-performing analytics and data science team.",
#     "Work with senior data scientists to develop and deliver innovative ML/AI solutions for various data science projects.\nInterest in the payments industry a plus.",
#     "Extensive management experience in data science or algorithm development.\n8+ years of management experience in data science or algorithm development.",
#     "Experience with building systems that operate on more than ten machines.\nParticipate in a code reviewing environment that encourages learning and high code\u2026",
#     "Provide insight and direction on roles and responsibilities required for data solution operations.\nData analytics: 10 years (Required).",
#     "Act as a Senior BI Developer, groom and review junior developers work.\nParticipate in the creation of a data warehouse.\nExcellent knowledge of BI concepts.",
#     "Research and development of machine learning algorithms to expand product capabilities.\nResearch and development of novel machine learning algorithms for the\u2026",
#     "Our end product is an API that makes financial transactions accessible to both humans and machine-learning models, in a scalable and privacy-preserving way.",
#     "Collaborate with data analysts/scientists and other team members to architect data products and services.\nExperience working with healthcare data is a plus.",
#     "Develop, test, implement and maintain new or modified software programs and procedures centered around our ML platform.",
#     "A background in machine learning frameworks such as TensorFlow is desirable but not essential.\nA commercial mindset and understanding of how to apply machine\u2026",
#     "Five (5) years of experience as a data scientist in a large financial firm.\nProvide a short statement on a recent quantitative analysis project you recently\u2026",
#     "It takes a scientist to analyze, evaluate, and maintain data so that it can be used to build, validate, and deploy _machine learning (ML) models_ that help SAIF\u2026",
#     "A background in machine learning frameworks such as TensorFlow is desirable but not essential.\nA commercial mindset and understanding of how to apply machine\u2026",
#     "Need Strong Data Scientist who has at least 5 years of relevant experience.\nPrior experience working in Financial domain will be a plus \u2013 NOT mandatory.",
#     "5+ years of experience working in data science or applied machine learning.\nUnderstand and manage technical and operational aspects of running machine learning\u2026",
#     "As a data scientist II in the analytics team, you will have a sound knowledge and experience Statistical Models, Data Mining, Machine Learning, building\u2026",
#     "Experience in Architect, design and implementing scalable ETL and data processing systems to handle the big data ecosystem including data collection, processing\u2026",
#     "Work closely with the account and client teams to assess measurement and data science solutions (e.g., incrementality testing, forecasting, attribution and\u2026",
#     "Professional position, which utilizes analytics and machine learning to the achieve business goals and objectives of the company.",
#     "Proficiency at understanding enterprise architecture concepts, master data management, data modeling and design techniques.\nThe Expertise and Skills You Bring.",
#     "Experience publishing RESTful API\u2019s to enable real-time data consumption using Open API specifications.\nImmediate Requirement for Big Data Engineer/AWS Data\u2026",
#     "Lead the customer data strategy across data science, engineering, and analytics, driving alignment with senior leadership team.",
#     "2+ years additional experience in business intelligence (BI) solutions in ETL or related information technology systems that support business processes.",
#     "You have hands-on experience developing data science solutions using open-source tools and cloud computing platforms.\nAt least 4 years\u2019 experience with SQL.",
#     "Five (5) years of experience as a data scientist in a large financial firm.\nProvide a short statement on a recent quantitative analysis project you recently\u2026",
#     "Experience with large data centric projects and data migration projects.\nAbility to learn and absorb existing and new data structures.",
#     "Deliver business value by translating complex data into meaningful insights, which will power MLB's products.\nTranslate business challenges into data pipelines \u2026",
#     "Leads data science development, contributes to problem-solving, and collaborates internally and externally on various research projects.",
#     "Work with the Data Engineering team to design and develop data models, ETL pipelines and data science projects.\nExperience with ETL/ELT data pipelines.",
#     "The Data Engineer will support our software developers, database architects, data analysts and data scientists on data initiatives and will ensure optimal data\u2026",
#     "Experience with data science algorithms such as advanced statistical methods, Machine Learning/Artificial Intelligence, Natural Language Processing (NLP)\u2026",
#     "Develop and deploy machine learning models for ad recommendation (CTR prediction, Personalization and user segmentation, Exploration/Exploitation Algos).",
#     "Prepare and analyze data for input into AI and machine learning models within client products.\nResearch, develop, and deploy the latest machine learning (ML)\u2026",
#     "5+ years in \u201cData Engineering\u201d for mid; 8+ years in \u201cData Engineering\u201d for Senior.",
#     "Prior experience supporting data scientists or machine learning engineers in a Project Management capacity; understanding of how traditional agile methodologies\u2026",
#     "Deep understanding of one of the following areas: AI, machine learning, or deep learning.\nWriting efficient, reusable, testable, and scalable code for core\u2026",
#     "Prior experience with machine learning frameworks such as PyTorch and Tensorflow.\nWork closely with data scientists and engineers to deploy models in our\u2026",
#     "Ability to perform detailed business analysis and design.\nProduce Ad Hoc Reports to answer business questions quickly and thoroughly.",
#     "Experience working with machine learning algorithms to solve classification and clustering problems, perform information retrieval from unstructured and semi\u2026",
#     "7+ years of overall software development and/or database engineering experience required.\n2+ years of hands-on development experience with event based streaming\u2026",
#     "Contribute to the development and application of analytical and data visualization tools.\nPhD. and extensive experience in computational biology, bioinformatics\u2026",
#     "Experience with data science, data engineering, and MLOps workflows in a traditional on-prem, hybrid cloud, or public cloud environment is highly desirable as\u2026",
#     "Assist data troubleshooting, data featuring and data discovery.\nMust possess 5+ years of experience with developing business intelligence solutions including\u2026",
#     "This Data Scientist will lead data science projects specific to developing business intelligence solutions that encompass data mining, data analytics, and\u2026",
#     "3 \u2013 8+ years of full-time data science experience, including applied techniques in modern data science and machine learning in production environments.",
#     "Demonstrable expertise in reinforcement learning and at least two of the following areas: natural language processing, computer vision, deep learning, augmented\u2026",
#     "Apply knowledge of statistics, machine learning, programming, data modeling, simulation, and advanced mathematics to recognize patterns, identify opportunities,\u2026",
#     "\\*\\*\\*Geospatial with machine learning experience*.\n\\*\\*Hands on experience in R / Python.*.\nFull in Machine learning or have some mixed up with Geo spatial exp\u2026",
#     "Implement machine learning algorithms and customized libraries.\nCollaborate with data engineers and data scientists to develop data and model pipelines.",
#     "We focus on developing enterprise decision making systems that solve existing problems across a range of industries using advanced machine learning,\u2026",
#     "2+ years of industry experience of applying machine learning at scale.\nYou will design, implement and integrate the next generation of Machine Learning\u2026",
#     "Create scripts/processes required to extract, transform, clean, and move data and metadata from a source application so they can be loaded into a data warehouse\u2026",
#     "Uses knowledge of business and data structure to discover and/or anticipate problems where data can be used to solve the problem.",
#     "Be a well-seasoned leader with expertise in healthcare analytics, data science and data warehousing.\nAnd experience with the development of data warehouses,\u2026",
#     "Demonstrated ability to analyze large data sets to identify gaps and inconsistencies, provide data insights, and advance effective product solutions.",
#     "Promote sound data science practices including pipeline development, source control, and performance monitoring.\nThe Data Science Director and team will.",
#     "Experience deploying machine learning workflows in AWS.\nExperience harnessing GPU infrastructure to perform machine learning tasks.",
#     "The Team consists of industry leaders in data science space, PHD/scholars from schools like MIT.\n\u2022 Experience with Visualization tools experience.*.",
#     "Closely work with the data engineering and data science teams.\n5+ years of data architecture and data management experience.\n2+ years of cloud experience.",
#     "Domain knowledge of data science & analytics workflows and/or data engineering.\nDrive projects in data science, analytics, and business intelligence Drive\u2026",
# ...
#     "The IT business analyst works with agency business units to assess processes, determine requirements, and deliver recommendations and reports to department\u2026",
#     "Experience developing business process documentation.\nCollaborate with SCC divisions/customers to identify business problems, opportunities, and improvements\u2026",
#     "Determine business objectives by studying development functions and evaluating output formats and requirements.\nExcellent written and oral communication skills.",
#     "Partner with IT and business process experts to articulate business requirements and ensure applications meet business needs.",
#     "Participates in business analyst tasks on information technology projects, problem tickets and provides support to other team members.",
#     "Analyze current business processes and document AS-IS business process flows.\nWork with business stakeholders in developing TO-BE business process flows.",
#     "The Senior CRM Business Analyst (Sr. BA) leverages the same foundational business analysis skills as a business analyst, additionally taking on complex, high\u2026",
#     "Participate in cross-functional teams to address business issues.\nAbility to document business requirements and translate into technical reporting\u2026",
#     "We value critical thinkers and creative problem solvers.\nThis is a full-time salaried position with benefits.\nProactively identify and solve problems.",
#     "Experience in an agile environment with an understanding of how each role performs to achieve team goals.\nExcellent analytical and problem-solving skills and\u2026",
#     "Individuals in this position have demonstrated experience in the standard concepts, practices, and deliverables related to Business Analysis in support of\u2026",
#     "Experience in gathering and documenting business requirements, as-is and to- be business process designs, functional configuration, testing, and user training.",
#     "Roles & Responsibilities \uf0b7 Engage with business stakeholders to translate business issues, pain points in to Business requirements, user stories that can be\u2026",
#     "Knowledge of business processes; ability to document business processes, generate clear and understandable requirements.",
#     "Collaborate with subject matter experts to develop business logic calculations and to document assumptions and data issues.",
#     "Works with subject matter experts and business intelligence developers to design specifications for custom report requests and extracts.",
#     "Strong business acumen and communication skills.\nThe employee will work across different business groups, including marketing, purchasing, and senior management\u2026",
#     "Experience analyzing and documenting business processes.\nGather, analyze, and document business requirements and translate into technical specifications,\u2026",
#     "Drives significant analytic initiatives in support of business strategies.\nGather, document, and analyze business reporting requirements.",
#     "Business systems analyst: 7 years (Required).\nThe business systems analyst elicits, gathers compiles and documents user requirements and translates them into\u2026",
#     "Communicate changes, enhancements, and modifications of business requirements.\nAnalyze business challenges, objectives and develop as is/to-be process diagrams.",
#     "Participates in cross-functional teams to address business issues.\nAbility to document business requirements and translate into technical reporting\u2026",
#     "Performs various development activities such as gathering requirements from business partners, writing SQL queries against underlying data sources and develop\u2026",
#     "Collecting and analyzing project business requirements, documenting them to define and inform the project team and/or client.",
#     "This role partners with business and technical staff to identify issues and opportunities using data analysis and technology solutions.",
#     "At least six years of experience.\nStrong communication, documentation, and management skill.\nPrior experience in integration projects.",
#     "Define configuration specifications and business analysis requirements.\nExperience in analysing data to draw business-relevant conclusions and in data\u2026",
#     "3+ years of experience as a business analyst in an agile software development team and cloud-based software preferred.\nExperience using JIRA is a plus.",
#     "Define configuration specifications and business analysis requirements.\nExperience in analysing data to draw business-relevant conclusions and in data\u2026",
#     "Experienced with business process reengineering and identifying new applications of technology to business problems to make business more effective.",
#     "Individuals in this position have demonstrated experience in the standard concepts, practices, and deliverables related to Business Analysis in support of\u2026",
#     "Analyze the business requirements by collaborating with design and construction project management stakeholders and IT Management, studying systems flow, data\u2026",
#     "5 years experience as a business analyst with a solid understanding of the requirements gathering process as part of the software development lifecycle \u201cSDLC\u201d.",
#     "Maintain analysis and business requirement documentation.\nInfluence stakeholders to support business projects.\nSupport ad-hoc projects/requests.",
#     "The Business Analyst is responsible for gathering business requirements and interpreting business needs into detailed requirements that can be easily understood\u2026",
#     "You have excellent interpersonal, persuasion, and communication skills to communicate strategic and technical ideas to science, engineering, and business\u2026",
#     "Designs, documents, and reengineers business processes and publishes business metric results.\nPerforms analyses of the business goals, objectives, and needs of\u2026",
#     "Experience with UML, Process Modeling, Data Analysis, Business requirement documentation, Use cases and flow charts.",
#     "Develop reporting solutions for all business areas based on business needs.\nAssistance with prioritization of incoming business requests.",
#     "The analyst would be dedicated to a global account.\nExperience in delivering and positioning value-added client/ business services.\nMust be a team player.",
#     "Troubleshooting and problem solving issues, as well as working closely with managers and developers, to solve these problems, will be needed.",
#     "You will be responsible for two distinct areas of responsibility: (1) leveraging their expertise in designing and executing on the analytic plans for key\u2026",
#     "Excellent analytical and problem-solving skills, combined with strong business judgement and an ability to present analysis in a clear and compelling manner.",
#     "Design the business requirement approach based on the project scope, and create Business Analysis using an agile methodology.",
#     "BA/BS required (major in an analytical field desired).\nA minimum of 5 to 10+ years\u2019 work-related experience.\nVersed on the agile methodology and best practices.",
#     "This is a \u201chands-on\u201d position requiring solid technical skills, as well as excellent interpersonal and communication skills, since you will be working directly\u2026",
#     "The role requires to Design, build, test and maintain enablers of business processes, including technology and process solutions with a focus on medium to high\u2026",
#     "Learning the business is fundamental to being successful in this role.\nYou will be able to learn and maintain a general knowledge of all products in the Company\u2026",
#     "Clearly communicate and document those business requirements into product backlog items.\nParticipate in the agile development process by attending stand ups,\u2026",
#     "The Business Analyst may be responsible for any of the following tasks: developing processes for internal and external systems, identifying business needs for\u2026",
#     "4+ years of experience within life sciences supporting the delivery of GxP validated global business systems serving cross-functional stakeholders.",
#     "One (1) year previous business analyst experience.\nExperience creating documentation such as business case documentation or business requirements summaries.",
#     "\u2022 Interact with business leads and stakeholders to understand business needs and provide guidance and/or solutions*.\nTeam Lead TL2 A4 SC1*.",
#     "The Business Analyst is responsible for the analysis and evaluation of business objectives and the development of innovative solutions to meet business\u2026",
#     "Leads business/functional requirements workshops and gather, evaluate, and detail customer business needs and requirements.",
#     "You will Partner with the business team leaders to translate business KPIs into Dashboards, Analysis and reporting.",
#     "Proven experience with business and technical requirements analysis, elicitation, modeling, verification, and methodology development.",
#     "Develop user stories that define the project business objectives.\nPerform analysis on the specific project business domain.\nTest plans: 5 years (Preferred)."
# ]
#
# Cluster id: 12
# Size: 31
# [
#     "Experience working with large datasets, batch and real-time data streaming.\nRelocation : Need to be onsite after Pandemic.",
#     "Good to have big data technologies \u2013 Apache Spark, Kafka, Delta Lake.\nData warehouse: 7 years (Preferred).",
#     "3+ year of Python experience required!\nStrong desire to learn and grow required!\nCompensation in line with industry forms.\nJob Types: Full-time, Contract.",
#     "We are looking for a senior engineer to build an extremely easy-to-use RPC and backend data and modeling platform based on unstructured data embedding to\u2026",
#     "You should understand data pipelines and modern ways of automating data using cloud-based and on-premise technologies.\n1-2 years working on AWS/Azure cloud.",
#     "5+ years of experience as Data Engineer.\n2-3 years of hands on exp on Snowflake.\nPerson needs to be local to Pittsburgh or ready to relocate to Pittsburgh to go\u2026",
#     "Duration: * Contract to hire (Full time).\n3+ years' experience in Python.\nExperience in using various Python libraries.",
#     "We need a senior Purview Subject matter expert with extensive Data Ingestion experience from Data Warehouses (SQL, AWS, Main Frame) to Purview.",
#     "And methodology, and data visualization (PowerBI, Tableau, etc.).\nSalary: * depending on relevant industry experience.\nA Day In The Life of a Data Engineer I*.",
#     "Designing and implementing highly performant data ingestion pipelines from multiple sources using Azure Databricks.\nSkills: Data Bricks, SQL Server, Power BI*.",
#     "I'm reaching out to you to check whether you are open/looking for a new contract opportunity for a *Data Engineer *remote role*.\nCI/CD: 5 years (Required).",
#     "Need to have exposure to Azure Data factory flow compilation of the converted data processing.\nVisa Type: US Citizen Only*.\nData Engineer: 4 years (Preferred).",
#     "We are looking for a data engineer who has passion for data integration technologies and comes with data warehousing background.",
#     "Languages: T-SQL or other SQL language Databases: MSSQL, Mongo, PostgreSQL Technologies: Apache Airflow, Docker or Kubernetes Platforms: Azure or Google Cloud\u2026",
#     "5+ years of experience as Data Engineer.\n2-3 years of hands on exp on Snowflake.\nPerson needs to be local to Pittsburgh or ready to relocate to Pittsburgh to go\u2026",
#     "We are looking for someone with strong hands-on experience with ADF ( Azure Data Factory) developer with HQL.\nJob Types: Full-time, Contract.",
#     "Need Data Engineer with Strong *SQL, Azure Data Factory (ADF), ADLS, ADB.*.\nData warehouse: 1 year (Required).",
#     "Big data: 5 years (Required).\nBig Data, Devops , Terraform, AWS , CI/CD pipeline.\nCI/CD: 4 years (Required).",
#     "3-5 years' experience in Python.\nExperience with Scripting \u2013 JavaScript preferred.\nMust be on-site day 1.\nCompensation in line with industry forms.",
#     "*3+ years of data engineering experience required!*.\nPrevious professional experience in Python on data site, NumPy, Pandas mandate.",
#     "Design and develop data pipelines.\n5 years hands-on experience designing and implementing multi-tenant solutions using Azure Databricks for data governance,\u2026",
#     "Need to have exposure to Azure Data factory flow compilation of the converted data processing.\nVisa Type: US Citizen Only*.\nData Engineer: 4 years (Preferred).",
#     "We have a great project and need Migration Engineers to assist with migration of an enterprise client to a new data center.",
#     "Proven experience on building data pipelines & Data Engineering systems.\nPython \u2013 5+ years of experience.\nProject \u2013 Long term (16 to 18 months).",
#     "Languages: T-SQL or other SQL language Databases: MSSQL, Mongo, PostgreSQL Technologies: Apache Airflow, Docker or Kubernetes Platforms: Azure or Google Cloud\u2026",
#     "Translate business requirements into technical specifications.\nAccess, transform, and format data to meet business needs.\nData warehouse: 7 years (Preferred).",
#     "We are looking for a data engineer who has passion for data integration technologies and comes with data warehousing background.",
#     "Exposure to writing code (Python preferred, R and SQL okay), collaboration (Git), developing models (machine learning, boosting & bagging algorithms, &/or\u2026",
#     "Senior Data Scientist / Data Science Manager / Lead Data Scientist 100% Remote C2H role within 3-6 months! Years of EXP-8-10 (Do not need people with 20-25\u2026",
#     "Software Skills Required: Teradata, SQL, ETL, Python*.",
#     "Candidates should be really strong in Python and SQL."
# ]
#
# Cluster id: 5
# Size: 6
# [
#     "Your direct manager will be a corporate-level executive in one functional area of the business.\nBy interfacing extensively with executives, operational managers\u2026",
#     "Responsible as project director with responsibility for project outcome and customer interaction.\nRecognizes and elevates changes in project scope or execution\u2026",
#     "Set Technical Direction for AI/ML/Data Science R&D project portfolio.\nCultivating relationships with DARPA Program Managers and other customers.",
#     "Responsible as project director with responsibility for project outcome and customer interaction.\nRecognizes and elevates changes in project scope or execution\u2026",
#     "Partner closely with cross-functional leaders to influence Net Zero strategy via data-driven insights.\nAbility to engage and influence executive stakeholders as\u2026",
#     "As manager of this team, you will own the vision for your group, build a roadmap to achieve your vision, and drive strategic impact with your stakeholders teams\u2026"
# ]
#
# Cluster id: 31
# Size: 6
# [
#     "We are looking for a Business Analyst.\nThis is a contract and Remote position and the project team is in Des Moines, IA.\nPay: $35.00 - $38.00 per hour.",
#     "AG is starting a project to replace their POS system with a new cloud based POS system and are looking for a Business analyst to support the engagement*.",
#     "Immediate interview for Business Analyst with 9+ years of recent banking experience required.\nAvailable to work on C2C ON NYC, NY / Alpharetta, GA.",
#     "As a Business Analyst New Graduate for Cisco you will develop creative solutions for real business challenges.",
#     "New training batch for Business Analyst in different domains.\nTraining provided by Remote full-time trainer with good working professional experience as a\u2026",
#     "AtlanticTransTrading is seeking a Business Analyst who is responsible for gathering, validating business requirements and involving in the development life\u2026"
# ]

# %%
df['cluster_label'] = test

# %%
df.reset_index(inplace=True)

# %%
lines =  df[['Unnamed: 0', 'Descriptions']]

# %%
df.head(2)
# Out:
#    index  Unnamed: 0             Title           Company     Location  Rating  \
# 0      0           0    Data Scientist     Driven Brands  Benicia, CA     2.4
# 1      1           1  Business Analyst  Sabot Consulting       Remote     NaN
#
#                        Date              Salary  \
# 0  PostedPosted 26 days ago                 NaN
# 1   PostedPosted 4 days ago  $80 - $120 an hour
#
#                                          Description  \
# 0  You’ll be working alongside a team of eight an...
# 1  Preferred candidates will have prior experienc...
#
#                                                Links  \
# 0  https://www.indeed.com/rc/clk?jk=74d176d595225...
# 1  https://www.indeed.com/rc/clk?jk=f662b2efb509b...
#
#                                         Descriptions  \
# 0  We invite you to join us at Driven Brands!\nHe...
# 1  Sabot Consulting (Sabot) is a management consu...
#
#                                                lines
# 0  0          0\n1          1\n2          2\n3   ...
# 1  0          0\n1          1\n2          2\n3   ...

# %%
top_clusters = get_topic_summaries_with_references("Python ", lines, top_cluster_size_threshold=0.2)
# Out:
# Calculating embeddings...
# done.
# (1200, 1536)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 top_clusters = get_topic_summaries_with_references("Python ", lines, top_cluster_size_threshold=0.2)
#
# Cell In[27], line 192, in get_topic_summaries_with_references(topic, comments, top_cluster_size_threshold)
#     190 clusters = defaultdict(list)
#     191 for x, cluster_label in zip(comments, clustering.labels_):
# --> 192     comment_number, comment_text = x
#     193     clusters[int(cluster_label)].append((comment_number, comment_text))
#     194 print("Num clusters: " + str(len(clusters.keys())))
#
# ValueError: too many values to unpack (expected 2)
